# %% [markdown]
# <a href="https://colab.research.google.com/github/jonghochoi/modern-cpp-features/blob/master/ProcTHOR_Tutorial.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %% [markdown]
# # Install AI2-THOR
#
# ProcTHOR houses are loaded into `ai2thor` and distributed with the `prior` package. We'll also install a helper package, called `ai2thor_colab`, which allows us to run AI2-THOR in Google Colab.
#
# Let's install each of these packages below:

# %%
# Here, we'll install and use a pre-release of AI2-THOR.
# !pip install --upgrade ai2thor --quiet
# !pip install ai2thor-colab prior --upgrade &> /dev/null

# %% [markdown]
# # Download ProcTHOR-10k
#
# Now, let's use the `prior` package to easily download the `procthor-10k` dataset:

# %%
import prior

dataset = prior.load_dataset("procthor-10k")
dataset
# Out:
# [AI2-THOR WARNING] There has been an update to ProcTHOR-10K that must be used with AI2-THOR version 5.0+. To use the new version of ProcTHOR-10K, please update AI2-THOR to version 5.0+ by running:
#     pip install --upgrade ai2thor
# Alternatively, to downgrade to the old version of ProcTHOR-10K, run:
#    prior.load_dataset("procthor-10k", revision="ab3cacd0fc17754d4c080a3fd50b18395fae8647")
# Loading train: 100%|██████████| 10000/10000 [00:02<00:00, 4250.59it/s]
# Loading val: 100%|██████████| 1000/1000 [00:00<00:00, 4437.11it/s]
# Loading test: 100%|██████████| 1000/1000 [00:00<00:00, 4282.62it/s]
# DatasetDict(
#     train=Dataset(
#     dataset=procthor-dataset,
#     size=10000,
#     split=train
# ),
#     val=Dataset(
#     dataset=procthor-dataset,
#     size=1000,
#     split=val
# ),
#     test=Dataset(
#     dataset=procthor-dataset,
#     size=1000,
#     split=test
# )
# )

# %% [markdown]
# ProcTHOR-10k comes with 3 splits, including:
# - 10k `"train"` houses
# - 1k `"val"` houses
# - 1k `"test"` houses
#
# these can be obtained by indexing into the dataset:

# %%
dataset["train"]
# Out:
# Dataset(
#     dataset=procthor-dataset,
#     size=10000,
#     split=train
# )

# %% [markdown]
# Here is an example of how to load a single house's JSON file:

# %%
house = dataset["train"][0]
type(house), house.keys(), house
# Out:
# (dict,
#  dict_keys(['doors', 'metadata', 'objects', 'proceduralParameters', 'rooms', 'walls', 'windows']),
#  {'doors': [{'assetId': 'Doorway_6',
#     'id': 'door|1|2',
#     'openable': False,
#     'openness': 0,
#     'room0': 'room|2',
#     'room1': 'room|2',
#     'wall0': 'wall|2|5.99|3.99|5.99|5.99',
#     'wall1': 'wall|exterior|5.99|3.99|5.99|5.99',
#     'holePolygon': [{'x': 0.4987163812589276, 'y': 0, 'z': 0},
#      {'x': 1.5362947256040203, 'y': 2.1068506240844727, 'z': 0}],
#     'assetPosition': {'x': 1.016530884310268,
#      'y': 1.0534253120422363,
#      'z': 0}}],
#   'metadata': {'agent': {'horizon': 30,
#     'position': {'x': 3.5, 'y': 0.95, 'z': 2.0},
#     'rotation': {'x': 0, 'y': 90, 'z': 0},
#     'standing': True},
#    'roomSpecId': 'kitchen',
#    'schema': '1.0.0',
#    'warnings': {},
#    'agentPoses': {'arm': {'horizon': 30,
#      'position': {'x': 3.5, 'y': 0.95, 'z': 2.0},
#      'rotation': {'x': 0, 'y': 90, 'z': 0},
#      'standing': True},
#     'default': {'horizon': 30,
#      'position': {'x': 3.5, 'y': 0.95, 'z': 2.0},
#      'rotation': {'x': 0, 'y': 90, 'z': 0},
#      'standing': True},
#     'locobot': {'horizon': 30,
#      'position': {'x': 3.5, 'y': 0.95, 'z': 2.0},
#      'rotation': {'x': 0, 'y': 90, 'z': 0}},
#     'stretch': {'horizon': 30,
#      'position': {'x': 3.5, 'y': 0.95, 'z': 2.0},
#      'rotation': {'x': 0, 'y': 90, 'z': 0},
#      'standing': True}}},
#   'objects': [{'assetId': 'Countertop_I_8x2',
#     'children': [{'assetId': 'Apple_24',
#       'id': 'Apple|surface|2|0',
#       'kinematic': False,
#       'position': {'x': 0.5637316703796387,
#        'y': 1.0042839050292969,
#        'z': 3.35530424118042},
#       'rotation': {'x': -0.0, 'y': 90.0, 'z': -0.0}},
#      {'assetId': 'Egg_23',
#       'id': 'Egg|surface|2|1',
#       'kinematic': False,
#       'position': {'x': 0.4870651662349701,
#        'y': 1.027331042289734,
#        'z': 3.6610817909240723},
#       'rotation': {'x': -0.0, 'y': 90.0, 'z': -0.0}},
#      {'assetId': 'Spray_Bottle_8',
#       'id': 'SprayBottle|surface|2|2',
#       'kinematic': False,
#       'position': {'x': 0.26057788729667664,
#        'y': 1.0662530660629272,
#        'z': 3.35606050491333},
#       'rotation': {'x': -0.0, 'y': 90.0, 'z': -0.0}},
#      {'assetId': 'Lettuce_19',
#       'id': 'Lettuce|surface|2|3',
#       'kinematic': False,
#       'position': {'x': 0.24332460761070251,
#        'y': 1.027500867843628,
#        'z': 2.745353937149048},
#       'rotation': {'x': -0.0, 'y': 90.0, 'z': -0.0}},
#      {'assetId': 'RoboTHOR_salt_pepper_shaker_bnyd_salt_v',
#       'id': 'SaltShaker|surface|2|4',
#       'kinematic': False,
#       'position': {'x': 0.3334498405456543,
#        'y': 0.9904139041900635,
#        'z': 3.6610817909240723},
#       'rotation': {'x': -0.0, 'y': 90.0, 'z': -0.0}},
#      {'assetId': 'Kettle_1',
#       'id': 'Kettle|surface|2|5',
#       'kinematic': False,
#       'position': {'x': 0.41322192549705505,
#        'y': 1.0344257354736328,
#        'z': 3.0510385036468506},
#       'rotation': {'x': -0.0, 'y': 90.0, 'z': -0.0}},
#      {'assetId': 'Kettle_1',
#       'id': 'Kettle|surface|2|6',
#       'kinematic': False,
#       'position': {'x': 0.489982545375824,
#        'y': 1.0344257354736328,
#        'z': 2.44099497795105},
#       'rotation': {'x': -0.0, 'y': 90.0, 'z': -0.0}},
#      {'assetId': 'Tomato_5',
#       'id': 'Tomato|surface|2|7',
#       'kinematic': False,
#       'position': {'x': 0.2566889822483063,
#        'y': 0.9945104718208313,
#        'z': 1.8300145864486694},
#       'rotation': {'x': -0.0, 'y': 90.0, 'z': -0.0}},
#      {'assetId': 'Wine_Bottle_1',
#       'id': 'WineBottle|surface|2|8',
#       'kinematic': False,
#       'position': {'x': 0.25668901205062866,
#        'y': 1.153962779045105,
#        'z': 2.1359734535217285},
#       'rotation': {'x': -0.0, 'y': 90.0, 'z': -0.0}},
#      {'assetId': 'Potato_6',
#       'id': 'Potato|surface|2|9',
#       'kinematic': False,
#       'position': {'x': 0.1779242604970932,
#        'y': 0.9769210815429688,
#        'z': 2.1421523094177246},
#       'rotation': {'x': -0.0, 'y': 0.0, 'z': 0.0}},
#      {'assetId': 'Bowl_22',
#       'id': 'Bowl|surface|2|11',
#       'kinematic': False,
#       'position': {'x': 0.25668907165527344,
#        'y': 1.0366127967834473,
#        'z': 2.4409947395324707},
#       'rotation': {'x': -0.0, 'y': 90.0, 'z': -0.0}},
#      {'assetId': 'Pencil_3',
#       'id': 'Pencil|surface|2|13',
#       'kinematic': False,
#       'position': {'x': 0.49016278982162476,
#        'y': 0.9471948742866516,
#        'z': 2.1359729766845703},
#       'rotation': {'x': -0.0, 'y': 90.0, 'z': -0.0}},
#      {'assetId': 'Soap_Bottle_3',
#       'id': 'SoapBottle|surface|2|14',
#       'kinematic': False,
#       'position': {'x': 0.4905245304107666,
#        'y': 1.0601518154144287,
#        'z': 2.74601674079895},
#       'rotation': {'x': -0.0, 'y': 90.0, 'z': -0.0}},
#      {'assetId': 'Plate_11',
#       'id': 'Plate|surface|2|15',
#       'kinematic': False,
#       'position': {'x': 0.1796281784772873,
#        'y': 1.0026221752166748,
#        'z': 3.0511207580566406},
#       'rotation': {'x': -0.0, 'y': 90.0, 'z': -0.0}},
#      {'assetId': 'Ladle_1',
#       'id': 'Ladle|surface|2|16',
#       'kinematic': False,
#       'position': {'x': 0.4116273522377014,
#        'y': 0.9665365219116211,
#        'z': 3.647871494293213},
#       'rotation': {'x': -0.0, 'y': 180.0, 'z': -0.0}},
#      {'assetId': 'Fork_1',
#       'id': 'Fork|surface|2|17',
#       'kinematic': False,
#       'position': {'x': 0.4102102816104889,
#        'y': 0.9532511234283447,
#        'z': 1.8531603813171387},
#       'rotation': {'x': -0.0, 'y': 180.0, 'z': -0.0}}],
#     'id': 'CounterTop|2|0',
#     'kinematic': True,
#     'position': {'x': 0.33027573823928835,
#      'y': 0.46873316168785095,
#      'z': 2.745277252197266},
#     'rotation': {'x': 0, 'y': 90, 'z': 0},
#     'material': None},
#    {'assetId': 'Fridge_19',
#     'children': [{'assetId': 'Lettuce_7',
#       'id': 'Lettuce|surface|2|10',
#       'kinematic': False,
#       'position': {'x': 5.091383457183838,
#        'y': 0.7108428478240967,
#        'z': 0.4495431184768677},
#       'rotation': {'x': -0.0, 'y': -0.00016733960364945233, 'z': 0.0}},
#      {'assetId': 'Potato_2',
#       'id': 'Potato|surface|2|12',
#       'kinematic': False,
#       'position': {'x': 5.086888313293457,
#        'y': 1.0534775257110596,
#        'z': 0.33588168025016785},
#       'rotation': {'x': -0.0, 'y': -0.00016733960364945233, 'z': 0.0}}],
#     'id': 'Fridge|2|1',
#     'kinematic': True,
#     'position': {'x': 5.394602856636048,
#      'y': 0.8955701589584351,
#      'z': 0.4535314679145813},
#     'rotation': {'x': 0, 'y': 0, 'z': 0},
#     'material': None},
#    {'assetId': 'Houseplant_11',
#     'id': 'HousePlant|2|2|0',
#     'kinematic': False,
#     'position': {'x': 2.1638059884110636,
#      'y': 0.44735240936279297,
#      'z': 0.4040222594694701},
#     'rotation': {'x': 0, 'y': 42.941641543344474, 'z': 0},
#     'material': None},
#    {'assetId': 'bin_25',
#     'id': 'GarbageCan|2|3',
#     'kinematic': False,
#     'position': {'x': 7.7613059598207474,
#      'y': 0.2631477117538452,
#      'z': 2.213693920969963},
#     'rotation': {'x': 0, 'y': 270, 'z': 0},
#     'material': None},
#    {'assetId': 'GarbageBag_21_2',
#     'id': 'GarbageBag|2|4',
#     'kinematic': False,
#     'position': {'x': 4.173373784882576,
#      'y': 0.2789691686630249,
#      'z': 3.4191244414432314},
#     'rotation': {'x': 0, 'y': 0, 'z': 0},
#     'material': None},
#    {'assetId': 'Wall_Decor_Photo_1V',
#     'id': 'Painting|2|5',
#     'kinematic': True,
#     'position': {'x': 0.8102974199756547,
#      'y': 1.4138685528004606,
#      'z': 0.020870485454797746},
#     'rotation': {'x': 0, 'y': 0, 'z': 0},
#     'material': None},
#    {'assetId': 'Wall_Decor_Photo_2',
#     'id': 'Painting|2|6',
#     'kinematic': True,
#     'position': {'x': 7.959129514545203,
#      'y': 1.331527213957422,
#      'z': 4.839191256680811},
#     'rotation': {'x': 0, 'y': 270, 'z': 0},
#     'material': None},
#    {'assetId': 'Wall_Decor_Painting_3V',
#     'id': 'Painting|2|7',
#     'kinematic': True,
#     'position': {'x': 3.0986902424464073,
#      'y': 1.7585664590494803,
#      'z': 0.020870485454797746},
#     'rotation': {'x': 0, 'y': 0, 'z': 0},
#     'material': None},
#    {'assetId': 'Wall_Decor_Photo_6',
#     'id': 'Painting|2|8',
#     'kinematic': True,
#     'position': {'x': 4.008591369226025,
#      'y': 1.6047140561531188,
#      'z': 0.020870485454797746},
#     'rotation': {'x': 0, 'y': 0, 'z': 0},
#     'material': None}],
#   'proceduralParameters': {'ceilingColor': {'b': 0.3058823529411765,
#     'g': 0.3843137254901961,
#     'r': 0.42745098039215684},
#    'ceilingMaterial': {'name': 'PureWhite',
#     'color': {'b': 0.3058823529411765,
#      'g': 0.3843137254901961,
#      'r': 0.42745098039215684}},
#    'floorColliderThickness': 1.0,
#    'lights': [{'id': 'DirectionalLight',
#      'indirectMultiplier': 1.0,
#      'intensity': 1,
#      'position': {'x': 0.84, 'y': 0.1855, 'z': -1.09},
#      'rgb': {'r': 1.0, 'g': 1.0, 'b': 1.0},
#      'rotation': {'x': 66, 'y': 75, 'z': 0},
#      'shadow': {'type': 'Soft',
#       'strength': 1,
#       'normalBias': 0,
#       'bias': 0,
#       'nearPlane': 0.2,
#       'resolution': 'FromQualitySettings'},
#      'type': 'directional'},
#     {'id': 'light_2',
#      'intensity': 0.45,
#      'position': {'x': 3.9899999999999998,
#       'y': 4.351928794929904,
#       'z': 2.49375},
#      'range': 15,
#      'rgb': {'r': 1.0, 'g': 0.855, 'b': 0.722},
#      'shadow': {'type': 'Soft',
#       'strength': 1,
#       'normalBias': 0,
#       'bias': 0.05,
#       'nearPlane': 0.2,
#       'resolution': 'FromQualitySettings'},
#      'type': 'point'}],
#    'receptacleHeight': 0.7,
#    'reflections': [],
#    'skyboxId': 'SkyAlbany'},
#   'rooms': [{'ceilings': [],
#     'children': [],
#     'floorMaterial': {'name': 'OrangeCabinet'},
#     'floorPolygon': [{'x': 0.0, 'y': 0, 'z': 0.0},
#      {'x': 0.0, 'y': 0, 'z': 3.99},
#      {'x': 5.985, 'y': 0, 'z': 3.99},
#      {'x': 5.985, 'y': 0, 'z': 5.985},
#      {'x': 7.98, 'y': 0, 'z': 5.985},
#      {'x': 7.98, 'y': 0, 'z': 1.995},
#      {'x': 5.985, 'y': 0, 'z': 1.995},
#      {'x': 5.985, 'y': 0, 'z': 0.0}],
#     'id': 'room|2',
#     'roomType': 'Kitchen'}],
#   'walls': [{'color': {'b': 0.27450980392156865,
#      'g': 0.25098039215686274,
#      'r': 0.3764705882352941},
#     'id': 'wall|2|0.00|0.00|0.00|3.99',
#     'material': {'name': 'PureWhite',
#      'color': {'b': 0.27450980392156865,
#       'g': 0.25098039215686274,
#       'r': 0.3764705882352941}},
#     'polygon': [{'x': 0.0, 'y': 0, 'z': 0.0},
#      {'x': 0.0, 'y': 0, 'z': 3.99},
#      {'x': 0.0, 'y': 4.551928794929904, 'z': 0.0},
#      {'x': 0.0, 'y': 4.551928794929904, 'z': 3.99}],
#     'roomId': 'room|2'},
#    {'color': {'b': 0.27450980392156865,
#      'g': 0.25098039215686274,
#      'r': 0.3764705882352941},
#     'id': 'wall|2|0.00|3.99|5.99|3.99',
#     'material': {'name': 'PureWhite',
#      'color': {'b': 0.27450980392156865,
#       'g': 0.25098039215686274,
#       'r': 0.3764705882352941}},
#     'polygon': [{'x': 0.0, 'y': 0, 'z': 3.99},
#      {'x': 5.985, 'y': 0, 'z': 3.99},
#      {'x': 0.0, 'y': 4.551928794929904, 'z': 3.99},
#      {'x': 5.985, 'y': 4.551928794929904, 'z': 3.99}],
#     'roomId': 'room|2'},
#    {'color': {'b': 0.27450980392156865,
#      'g': 0.25098039215686274,
#      'r': 0.3764705882352941},
#     'id': 'wall|2|5.99|3.99|5.99|5.99',
#     'material': {'name': 'PureWhite',
#      'color': {'b': 0.27450980392156865,
#       'g': 0.25098039215686274,
#       'r': 0.3764705882352941}},
#     'polygon': [{'x': 5.985, 'y': 0, 'z': 3.99},
#      {'x': 5.985, 'y': 0, 'z': 5.985},
#      {'x': 5.985, 'y': 4.551928794929904, 'z': 3.99},
#      {'x': 5.985, 'y': 4.551928794929904, 'z': 5.985}],
#     'roomId': 'room|2'},
#    {'color': {'b': 0.27450980392156865,
#      'g': 0.25098039215686274,
#      'r': 0.3764705882352941},
#     'id': 'wall|2|5.99|5.99|7.98|5.99',
#     'material': {'name': 'PureWhite',
#      'color': {'b': 0.27450980392156865,
#       'g': 0.25098039215686274,
#       'r': 0.3764705882352941}},
#     'polygon': [{'x': 5.985, 'y': 0, 'z': 5.985},
#      {'x': 7.98, 'y': 0, 'z': 5.985},
#      {'x': 5.985, 'y': 4.551928794929904, 'z': 5.985},
#      {'x': 7.98, 'y': 4.551928794929904, 'z': 5.985}],
#     'roomId': 'room|2'},
#    {'color': {'b': 0.27450980392156865,
#      'g': 0.25098039215686274,
#      'r': 0.3764705882352941},
#     'id': 'wall|2|7.98|2.00|7.98|5.99',
#     'material': {'name': 'PureWhite',
#      'color': {'b': 0.27450980392156865,
#       'g': 0.25098039215686274,
#       'r': 0.3764705882352941}},
#     'polygon': [{'x': 7.98, 'y': 0, 'z': 5.985},
#      {'x': 7.98, 'y': 0, 'z': 1.995},
#      {'x': 7.98, 'y': 4.551928794929904, 'z': 5.985},
#      {'x': 7.98, 'y': 4.551928794929904, 'z': 1.995}],
#     'roomId': 'room|2'},
#    {'color': {'b': 0.27450980392156865,
#      'g': 0.25098039215686274,
#      'r': 0.3764705882352941},
#     'id': 'wall|2|5.99|2.00|7.98|2.00',
#     'material': {'name': 'PureWhite',
#      'color': {'b': 0.27450980392156865,
#       'g': 0.25098039215686274,
#       'r': 0.3764705882352941}},
#     'polygon': [{'x': 7.98, 'y': 0, 'z': 1.995},
#      {'x': 5.985, 'y': 0, 'z': 1.995},
#      {'x': 7.98, 'y': 4.551928794929904, 'z': 1.995},
#      {'x': 5.985, 'y': 4.551928794929904, 'z': 1.995}],
#     'roomId': 'room|2'},
#    {'color': {'b': 0.27450980392156865,
#      'g': 0.25098039215686274,
#      'r': 0.3764705882352941},
#     'id': 'wall|2|5.99|0.00|5.99|2.00',
#     'material': {'name': 'PureWhite',
#      'color': {'b': 0.27450980392156865,
#       'g': 0.25098039215686274,
#       'r': 0.3764705882352941}},
#     'polygon': [{'x': 5.985, 'y': 0, 'z': 1.995},
#      {'x': 5.985, 'y': 0, 'z': 0.0},
#      {'x': 5.985, 'y': 4.551928794929904, 'z': 1.995},
#      {'x': 5.985, 'y': 4.551928794929904, 'z': 0.0}],
#     'roomId': 'room|2'},
#    {'color': {'b': 0.27450980392156865,
#      'g': 0.25098039215686274,
#      'r': 0.3764705882352941},
#     'id': 'wall|2|0.00|0.00|5.99|0.00',
#     'material': {'name': 'PureWhite',
#      'color': {'b': 0.27450980392156865,
#       'g': 0.25098039215686274,
#       'r': 0.3764705882352941}},
#     'polygon': [{'x': 5.985, 'y': 0, 'z': 0.0},
#      {'x': 0.0, 'y': 0, 'z': 0.0},
#      {'x': 5.985, 'y': 4.551928794929904, 'z': 0.0},
#      {'x': 0.0, 'y': 4.551928794929904, 'z': 0.0}],
#     'roomId': 'room|2'},
#    {'id': 'wall|exterior|0.00|0.00|5.99|0.00',
#     'material': {'name': 'LivingRoomFireplacebrickTex'},
#     'polygon': [{'x': 0.0, 'y': 4.551928794929904, 'z': 0.0},
#      {'x': 5.985, 'y': 4.551928794929904, 'z': 0.0},
#      {'x': 0.0, 'y': 0, 'z': 0.0},
#      {'x': 5.985, 'y': 0, 'z': 0.0}],
#     'roomId': 'exterior'},
#    {'id': 'wall|exterior|0.00|0.00|0.00|3.99',
#     'material': {'name': 'LivingRoomFireplacebrickTex'},
#     'polygon': [{'x': 0.0, 'y': 4.551928794929904, 'z': 3.99},
#      {'x': 0.0, 'y': 4.551928794929904, 'z': 0.0},
#      {'x': 0.0, 'y': 0, 'z': 3.99},
#      {'x': 0.0, 'y': 0, 'z': 0.0}],
#     'roomId': 'exterior'},
#    {'id': 'wall|exterior|0.00|3.99|5.99|3.99',
#     'material': {'name': 'LivingRoomFireplacebrickTex'},
#     'polygon': [{'x': 5.985, 'y': 4.551928794929904, 'z': 3.99},
#      {'x': 0.0, 'y': 4.551928794929904, 'z': 3.99},
#      {'x': 5.985, 'y': 0, 'z': 3.99},
#      {'x': 0.0, 'y': 0, 'z': 3.99}],
#     'roomId': 'exterior'},
#    {'id': 'wall|exterior|5.99|5.99|7.98|5.99',
#     'material': {'name': 'LivingRoomFireplacebrickTex'},
#     'polygon': [{'x': 7.98, 'y': 4.551928794929904, 'z': 5.985},
#      {'x': 5.985, 'y': 4.551928794929904, 'z': 5.985},
#      {'x': 7.98, 'y': 0, 'z': 5.985},
#      {'x': 5.985, 'y': 0, 'z': 5.985}],
#     'roomId': 'exterior'},
#    {'id': 'wall|exterior|5.99|0.00|5.99|2.00',
#     'material': {'name': 'LivingRoomFireplacebrickTex'},
#     'polygon': [{'x': 5.985, 'y': 4.551928794929904, 'z': 0.0},
#      {'x': 5.985, 'y': 4.551928794929904, 'z': 1.995},
#      {'x': 5.985, 'y': 0, 'z': 0.0},
#      {'x': 5.985, 'y': 0, 'z': 1.995}],
#     'roomId': 'exterior'},
#    {'id': 'wall|exterior|5.99|2.00|7.98|2.00',
#     'material': {'name': 'LivingRoomFireplacebrickTex'},
#     'polygon': [{'x': 5.985, 'y': 4.551928794929904, 'z': 1.995},
#      {'x': 7.98, 'y': 4.551928794929904, 'z': 1.995},
#      {'x': 5.985, 'y': 0, 'z': 1.995},
#      {'x': 7.98, 'y': 0, 'z': 1.995}],
#     'roomId': 'exterior'},
#    {'id': 'wall|exterior|5.99|3.99|5.99|5.99',
#     'material': {'name': 'LivingRoomFireplacebrickTex'},
#     'polygon': [{'x': 5.985, 'y': 4.551928794929904, 'z': 5.985},
#      {'x': 5.985, 'y': 4.551928794929904, 'z': 3.99},
#      {'x': 5.985, 'y': 0, 'z': 5.985},
#      {'x': 5.985, 'y': 0, 'z': 3.99}],
#     'roomId': 'exterior'},
#    {'id': 'wall|exterior|7.98|2.00|7.98|5.99',
#     'material': {'name': 'LivingRoomFireplacebrickTex'},
#     'polygon': [{'x': 7.98, 'y': 4.551928794929904, 'z': 1.995},
#      {'x': 7.98, 'y': 4.551928794929904, 'z': 5.985},
#      {'x': 7.98, 'y': 0, 'z': 1.995},
#      {'x': 7.98, 'y': 0, 'z': 5.985}],
#     'roomId': 'exterior'}],
#   'windows': []})

# %% [markdown]
# # Load a house into AI2-THOR
#
# First, let's import in a Controller from AI2-THOR:

# %%
from ai2thor.controller import Controller

# %% [markdown]
# To run AI2-THOR in Google Colab, we need to start an xserver, which allows us to load and observe images from the AI2-THOR Unity application, without having an external monitor or a GPU. Here, we'll use `ai2thor_colab`'s `start_xserver` function:

# %%
import ai2thor_colab
ai2thor_colab.start_xserver()
# Out:
#             <progress value='100' max="100", style='width: 100%'>
#                 100
#             </progress>

# %% [markdown]
# Let's now choose a ProcTHOR house we want to load into AI2-THOR:

# %%
house = dataset["train"][3]

# %% [markdown]
# And create a Controller that is initialized to that scene:

# %%
controller = Controller(scene=house)
# Out:
# thor-Linux64-f0825767cd50d69f666c7f282e54abfe58f1e917.zip: [ 100%  16.1 MiB/s]  of 769.MB

# %% [markdown]
# # Egocentric Images

# %% [markdown]
# We now have an agent placed in the scene ready to execute actions! Let's check out what it's looking at:

# %%
from PIL import Image

Image.fromarray(controller.last_event.frame)
# Out:
# <PIL.Image.Image image mode=RGB size=300x300 at 0x7FF2131483D0>

# %% [markdown]
# # Navigation Actions
#
# And take a few steps around:

# %%
event = controller.step(action="RotateRight")
Image.fromarray(event.frame)
# Out:
# <PIL.Image.Image image mode=RGB size=300x300 at 0x7FF211209BB0>

# %%
event = controller.step(action="RotateRight")
Image.fromarray(event.frame)
# Out:
# <PIL.Image.Image image mode=RGB size=300x300 at 0x7FF211209AF0>

# %%
event = controller.step(action="LookUp")
Image.fromarray(event.frame)
# Out:
# <PIL.Image.Image image mode=RGB size=300x300 at 0x7FF211209A90>

# %%
event = controller.step(action="MoveAhead")
Image.fromarray(event.frame)
# Out:
# <PIL.Image.Image image mode=RGB size=300x300 at 0x7FF211209760>

# %% [markdown]
# # Top-Down Frame
#
# We can also get a top-down image of the frame:

# %%
import copy

def get_top_down_frame():
    # Setup the top-down camera
    event = controller.step(action="GetMapViewCameraProperties", raise_for_failure=True)
    pose = copy.deepcopy(event.metadata["actionReturn"])

    bounds = event.metadata["sceneBounds"]["size"]
    max_bound = max(bounds["x"], bounds["z"])

    pose["fieldOfView"] = 50
    pose["position"]["y"] += 1.1 * max_bound
    pose["orthographic"] = False
    pose["farClippingPlane"] = 50
    del pose["orthographicSize"]

    # add the camera to the scene
    event = controller.step(
        action="AddThirdPartyCamera",
        **pose,
        skyboxColor="white",
        raise_for_failure=True,
    )
    top_down_frame = event.third_party_camera_frames[-1]
    return Image.fromarray(top_down_frame)


get_top_down_frame()
# Out:
# <PIL.Image.Image image mode=RGB size=300x300 at 0x7FF210F9A550>

# %% [markdown]
# # Randomize the Agent's Position
#
# To randomize the agent's position, we can get the set of grid positions that the agent can reach from 90 degree rotations and 0.25m separated movements. Here, we'll call `GetReachablePositions`:

# %%
event = controller.step(action="GetReachablePositions")
event.metadata["actionReturn"]
# Out:
# [{'x': 3.0, 'y': 0.9009997844696045, 'z': 5.0},
#  {'x': 3.25, 'y': 0.9009997844696045, 'z': 5.0},
#  {'x': 3.0, 'y': 0.9009997844696045, 'z': 5.25},
#  {'x': 2.75, 'y': 0.9009997844696045, 'z': 5.0},
#  {'x': 3.0, 'y': 0.9009997844696045, 'z': 4.75},
#  {'x': 3.5, 'y': 0.9009997844696045, 'z': 5.0},
#  {'x': 3.25, 'y': 0.9009997844696045, 'z': 5.25},
#  {'x': 3.25, 'y': 0.9009997844696045, 'z': 4.75},
#  {'x': 3.0, 'y': 0.9009997844696045, 'z': 5.5},
#  {'x': 2.75, 'y': 0.9009997844696045, 'z': 5.25},
#  {'x': 2.5, 'y': 0.9009997844696045, 'z': 5.0},
#  {'x': 2.75, 'y': 0.9009997844696045, 'z': 4.75},
#  {'x': 3.0, 'y': 0.9009997844696045, 'z': 4.5},
#  {'x': 3.75, 'y': 0.9009997844696045, 'z': 5.0},
#  {'x': 3.5, 'y': 0.9009997844696045, 'z': 5.25},
#  {'x': 3.5, 'y': 0.9009997844696045, 'z': 4.75},
#  {'x': 3.25, 'y': 0.9009997844696045, 'z': 5.5},
#  {'x': 3.25, 'y': 0.9009997844696045, 'z': 4.5},
#  {'x': 3.0, 'y': 0.9009997844696045, 'z': 5.75},
#  {'x': 2.75, 'y': 0.9009997844696045, 'z': 5.5},
#  {'x': 2.5, 'y': 0.9009997844696045, 'z': 5.25},
#  {'x': 2.25, 'y': 0.9009997844696045, 'z': 5.0},
#  {'x': 2.5, 'y': 0.9009997844696045, 'z': 4.75},
#  {'x': 2.75, 'y': 0.9009997844696045, 'z': 4.5},
#  {'x': 3.0, 'y': 0.9009997844696045, 'z': 4.25},
#  {'x': 4.0, 'y': 0.9009997844696045, 'z': 5.0},
#  {'x': 3.75, 'y': 0.9009997844696045, 'z': 5.25},
#  {'x': 3.75, 'y': 0.9009997844696045, 'z': 4.75},
#  {'x': 3.5, 'y': 0.9009997844696045, 'z': 5.5},
#  {'x': 3.5, 'y': 0.9009997844696045, 'z': 4.5},
#  {'x': 3.25, 'y': 0.9009997844696045, 'z': 5.75},
#  {'x': 3.25, 'y': 0.9009997844696045, 'z': 4.25},
#  {'x': 2.75, 'y': 0.9009997844696045, 'z': 5.75},
#  {'x': 2.5, 'y': 0.9009997844696045, 'z': 5.5},
#  {'x': 2.25, 'y': 0.9009997844696045, 'z': 5.25},
#  {'x': 2.0, 'y': 0.9009997844696045, 'z': 5.0},
#  {'x': 2.25, 'y': 0.9009997844696045, 'z': 4.75},
#  {'x': 2.5, 'y': 0.9009997844696045, 'z': 4.5},
#  {'x': 2.75, 'y': 0.9009997844696045, 'z': 4.25},
#  {'x': 3.0, 'y': 0.9009997844696045, 'z': 4.0},
#  {'x': 4.25, 'y': 0.9009997844696045, 'z': 5.0},
#  {'x': 4.0, 'y': 0.9009997844696045, 'z': 5.25},
#  {'x': 4.0, 'y': 0.9009997844696045, 'z': 4.75},
#  {'x': 3.75, 'y': 0.9009997844696045, 'z': 5.5},
#  {'x': 3.75, 'y': 0.9009997844696045, 'z': 4.5},
#  {'x': 3.5, 'y': 0.9009997844696045, 'z': 5.75},
#  {'x': 3.5, 'y': 0.9009997844696045, 'z': 4.25},
#  {'x': 3.25, 'y': 0.9009997844696045, 'z': 4.0},
#  {'x': 2.5, 'y': 0.9009997844696045, 'z': 5.75},
#  {'x': 2.25, 'y': 0.9009997844696045, 'z': 5.5},
#  {'x': 2.0, 'y': 0.9009997844696045, 'z': 5.25},
#  {'x': 1.75, 'y': 0.9009997844696045, 'z': 5.0},
#  {'x': 2.0, 'y': 0.9009997844696045, 'z': 4.75},
#  {'x': 2.25, 'y': 0.9009997844696045, 'z': 4.5},
#  {'x': 2.5, 'y': 0.9009997844696045, 'z': 4.25},
#  {'x': 2.75, 'y': 0.9009997844696045, 'z': 4.0},
#  {'x': 3.0, 'y': 0.9009997844696045, 'z': 3.75},
#  {'x': 4.5, 'y': 0.9009997844696045, 'z': 5.0},
#  {'x': 4.25, 'y': 0.9009997844696045, 'z': 5.25},
#  {'x': 4.25, 'y': 0.9009997844696045, 'z': 4.75},
#  {'x': 4.0, 'y': 0.9009997844696045, 'z': 5.5},
#  {'x': 4.0, 'y': 0.9009997844696045, 'z': 4.5},
#  {'x': 3.75, 'y': 0.9009997844696045, 'z': 5.75},
#  {'x': 3.75, 'y': 0.9009997844696045, 'z': 4.25},
#  {'x': 3.5, 'y': 0.9009997844696045, 'z': 6.0},
#  {'x': 3.5, 'y': 0.9009997844696045, 'z': 4.0},
#  {'x': 3.25, 'y': 0.9009997844696045, 'z': 3.75},
#  {'x': 2.0, 'y': 0.9009997844696045, 'z': 5.5},
#  {'x': 1.75, 'y': 0.9009997844696045, 'z': 5.25},
#  {'x': 1.5, 'y': 0.9009997844696045, 'z': 5.0},
#  {'x': 1.75, 'y': 0.9009997844696045, 'z': 4.75},
#  {'x': 2.0, 'y': 0.9009997844696045, 'z': 4.5},
#  {'x': 2.25, 'y': 0.9009997844696045, 'z': 4.25},
#  {'x': 2.5, 'y': 0.9009997844696045, 'z': 4.0},
#  {'x': 2.75, 'y': 0.9009997844696045, 'z': 3.75},
#  {'x': 4.75, 'y': 0.9009997844696045, 'z': 5.0},
#  {'x': 4.5, 'y': 0.9009997844696045, 'z': 5.25},
#  {'x': 4.5, 'y': 0.9009997844696045, 'z': 4.75},
#  {'x': 4.25, 'y': 0.9009997844696045, 'z': 5.5},
#  {'x': 4.25, 'y': 0.9009997844696045, 'z': 4.5},
#  {'x': 4.0, 'y': 0.9009997844696045, 'z': 5.75},
#  {'x': 4.0, 'y': 0.9009997844696045, 'z': 4.25},
#  {'x': 3.75, 'y': 0.9009997844696045, 'z': 6.0},
#  {'x': 3.75, 'y': 0.9009997844696045, 'z': 4.0},
#  {'x': 3.5, 'y': 0.9009997844696045, 'z': 3.75},
#  {'x': 1.75, 'y': 0.9009997844696045, 'z': 5.5},
#  {'x': 1.5, 'y': 0.9009997844696045, 'z': 5.25},
#  {'x': 1.25, 'y': 0.9009997844696045, 'z': 5.0},
#  {'x': 1.5, 'y': 0.9009997844696045, 'z': 4.75},
#  {'x': 1.75, 'y': 0.9009997844696045, 'z': 4.5},
#  {'x': 2.0, 'y': 0.9009997844696045, 'z': 4.25},
#  {'x': 2.25, 'y': 0.9009997844696045, 'z': 4.0},
#  {'x': 2.5, 'y': 0.9009997844696045, 'z': 3.75},
#  {'x': 5.0, 'y': 0.9009997844696045, 'z': 5.0},
#  {'x': 4.75, 'y': 0.9009997844696045, 'z': 5.25},
#  {'x': 4.75, 'y': 0.9009997844696045, 'z': 4.75},
#  {'x': 4.5, 'y': 0.9009997844696045, 'z': 4.5},
#  {'x': 4.25, 'y': 0.9009997844696045, 'z': 5.75},
#  {'x': 4.25, 'y': 0.9009997844696045, 'z': 4.25},
#  {'x': 4.0, 'y': 0.9009997844696045, 'z': 6.0},
#  {'x': 4.0, 'y': 0.9009997844696045, 'z': 4.0},
#  {'x': 3.75, 'y': 0.9009997844696045, 'z': 3.75},
#  {'x': 1.5, 'y': 0.9009997844696045, 'z': 5.5},
#  {'x': 1.25, 'y': 0.9009997844696045, 'z': 5.25},
#  {'x': 1.0, 'y': 0.9009997844696045, 'z': 5.0},
#  {'x': 1.25, 'y': 0.9009997844696045, 'z': 4.75},
#  {'x': 1.5, 'y': 0.9009997844696045, 'z': 4.5},
#  {'x': 1.75, 'y': 0.9009997844696045, 'z': 4.25},
#  {'x': 2.0, 'y': 0.9009997844696045, 'z': 4.0},
#  {'x': 2.25, 'y': 0.9009997844696045, 'z': 3.75},
#  {'x': 5.25, 'y': 0.9009997844696045, 'z': 5.0},
#  {'x': 5.0, 'y': 0.9009997844696045, 'z': 5.25},
#  {'x': 5.0, 'y': 0.9009997844696045, 'z': 4.75},
#  {'x': 4.75, 'y': 0.9009997844696045, 'z': 4.5},
#  {'x': 4.5, 'y': 0.9009997844696045, 'z': 4.25},
#  {'x': 4.25, 'y': 0.9009997844696045, 'z': 6.0},
#  {'x': 4.25, 'y': 0.9009997844696045, 'z': 4.0},
#  {'x': 4.0, 'y': 0.9009997844696045, 'z': 3.75},
#  {'x': 1.25, 'y': 0.9009997844696045, 'z': 5.5},
#  {'x': 1.0, 'y': 0.9009997844696045, 'z': 5.25},
#  {'x': 0.75, 'y': 0.9009997844696045, 'z': 5.0},
#  {'x': 1.0, 'y': 0.9009997844696045, 'z': 4.75},
#  {'x': 1.25, 'y': 0.9009997844696045, 'z': 4.5},
#  {'x': 1.5, 'y': 0.9009997844696045, 'z': 4.25},
#  {'x': 1.75, 'y': 0.9009997844696045, 'z': 4.0},
#  {'x': 2.0, 'y': 0.9009997844696045, 'z': 3.75},
#  {'x': 2.25, 'y': 0.9009997844696045, 'z': 3.5},
#  {'x': 5.5, 'y': 0.9009997844696045, 'z': 5.0},
#  {'x': 5.25, 'y': 0.9009997844696045, 'z': 5.25},
#  {'x': 5.25, 'y': 0.9009997844696045, 'z': 4.75},
#  {'x': 5.0, 'y': 0.9009997844696045, 'z': 4.5},
#  {'x': 4.75, 'y': 0.9009997844696045, 'z': 4.25},
#  {'x': 4.5, 'y': 0.9009997844696045, 'z': 4.0},
#  {'x': 4.25, 'y': 0.9009997844696045, 'z': 3.75},
#  {'x': 4.0, 'y': 0.9009997844696045, 'z': 3.5},
#  {'x': 1.25, 'y': 0.9009997844696045, 'z': 5.75},
#  {'x': 1.0, 'y': 0.9009997844696045, 'z': 5.5},
#  {'x': 0.5, 'y': 0.9009997844696045, 'z': 5.0},
#  {'x': 0.75, 'y': 0.9009997844696045, 'z': 4.75},
#  {'x': 1.0, 'y': 0.9009997844696045, 'z': 4.5},
#  {'x': 1.25, 'y': 0.9009997844696045, 'z': 4.25},
#  {'x': 1.5, 'y': 0.9009997844696045, 'z': 4.0},
#  {'x': 1.75, 'y': 0.9009997844696045, 'z': 3.75},
#  {'x': 2.0, 'y': 0.9009997844696045, 'z': 3.5},
#  {'x': 2.25, 'y': 0.9009997844696045, 'z': 3.25},
#  {'x': 5.75, 'y': 0.9009997844696045, 'z': 5.0},
#  {'x': 5.5, 'y': 0.9009997844696045, 'z': 5.25},
#  {'x': 5.5, 'y': 0.9009997844696045, 'z': 4.75},
#  {'x': 5.25, 'y': 0.9009997844696045, 'z': 5.5},
#  {'x': 5.25, 'y': 0.9009997844696045, 'z': 4.5},
#  {'x': 5.0, 'y': 0.9009997844696045, 'z': 4.25},
#  {'x': 4.75, 'y': 0.9009997844696045, 'z': 4.0},
#  {'x': 4.5, 'y': 0.9009997844696045, 'z': 3.75},
#  {'x': 4.25, 'y': 0.9009997844696045, 'z': 3.5},
#  {'x': 4.0, 'y': 0.9009997844696045, 'z': 3.25},
#  {'x': 1.25, 'y': 0.9009997844696045, 'z': 6.0},
#  {'x': 1.0, 'y': 0.9009997844696045, 'z': 5.75},
#  {'x': 0.5, 'y': 0.9009997844696045, 'z': 4.75},
#  {'x': 0.75, 'y': 0.9009997844696045, 'z': 4.5},
#  {'x': 1.0, 'y': 0.9009997844696045, 'z': 4.25},
#  {'x': 1.25, 'y': 0.9009997844696045, 'z': 4.0},
#  {'x': 1.5, 'y': 0.9009997844696045, 'z': 3.75},
#  {'x': 1.75, 'y': 0.9009997844696045, 'z': 3.5},
#  {'x': 2.0, 'y': 0.9009997844696045, 'z': 3.25},
#  {'x': 2.25, 'y': 0.9009997844696045, 'z': 3.0},
#  {'x': 6.0, 'y': 0.9009997844696045, 'z': 5.0},
#  {'x': 5.75, 'y': 0.9009997844696045, 'z': 4.75},
#  {'x': 5.5, 'y': 0.9009997844696045, 'z': 5.5},
#  {'x': 5.5, 'y': 0.9009997844696045, 'z': 4.5},
#  {'x': 5.25, 'y': 0.9009997844696045, 'z': 5.75},
#  {'x': 5.25, 'y': 0.9009997844696045, 'z': 4.25},
#  {'x': 5.0, 'y': 0.9009997844696045, 'z': 4.0},
#  {'x': 4.75, 'y': 0.9009997844696045, 'z': 3.75},
#  {'x': 4.5, 'y': 0.9009997844696045, 'z': 3.5},
#  {'x': 4.25, 'y': 0.9009997844696045, 'z': 3.25},
#  {'x': 4.0, 'y': 0.9009997844696045, 'z': 3.0},
#  {'x': 1.0, 'y': 0.9009997844696045, 'z': 6.0},
#  {'x': 0.5, 'y': 0.9009997844696045, 'z': 4.5},
#  {'x': 0.75, 'y': 0.9009997844696045, 'z': 4.25},
#  {'x': 1.0, 'y': 0.9009997844696045, 'z': 4.0},
#  {'x': 1.25, 'y': 0.9009997844696045, 'z': 3.75},
#  {'x': 1.5, 'y': 0.9009997844696045, 'z': 3.5},
#  {'x': 1.75, 'y': 0.9009997844696045, 'z': 3.25},
#  {'x': 2.0, 'y': 0.9009997844696045, 'z': 3.0},
#  {'x': 2.25, 'y': 0.9009997844696045, 'z': 2.75},
#  {'x': 6.25, 'y': 0.9009997844696045, 'z': 5.0},
#  {'x': 6.0, 'y': 0.9009997844696045, 'z': 4.75},
#  {'x': 5.75, 'y': 0.9009997844696045, 'z': 4.5},
#  {'x': 5.5, 'y': 0.9009997844696045, 'z': 5.75},
#  {'x': 5.5, 'y': 0.9009997844696045, 'z': 4.25},
#  {'x': 5.25, 'y': 0.9009997844696045, 'z': 6.0},
#  {'x': 5.25, 'y': 0.9009997844696045, 'z': 4.0},
#  {'x': 5.0, 'y': 0.9009997844696045, 'z': 3.75},
#  {'x': 4.75, 'y': 0.9009997844696045, 'z': 3.5},
#  {'x': 4.5, 'y': 0.9009997844696045, 'z': 3.25},
#  {'x': 4.25, 'y': 0.9009997844696045, 'z': 3.0},
#  {'x': 4.0, 'y': 0.9009997844696045, 'z': 2.75},
#  {'x': 0.5, 'y': 0.9009997844696045, 'z': 4.25},
#  {'x': 0.75, 'y': 0.9009997844696045, 'z': 4.0},
#  {'x': 1.0, 'y': 0.9009997844696045, 'z': 3.75},
#  {'x': 1.25, 'y': 0.9009997844696045, 'z': 3.5},
#  {'x': 1.5, 'y': 0.9009997844696045, 'z': 3.25},
#  {'x': 1.75, 'y': 0.9009997844696045, 'z': 3.0},
#  {'x': 2.0, 'y': 0.9009997844696045, 'z': 2.75},
#  {'x': 2.25, 'y': 0.9009997844696045, 'z': 2.5},
#  {'x': 6.5, 'y': 0.9009997844696045, 'z': 5.0},
#  {'x': 6.25, 'y': 0.9009997844696045, 'z': 4.75},
#  {'x': 6.0, 'y': 0.9009997844696045, 'z': 4.5},
#  {'x': 5.75, 'y': 0.9009997844696045, 'z': 4.25},
#  {'x': 5.5, 'y': 0.9009997844696045, 'z': 6.0},
#  {'x': 5.5, 'y': 0.9009997844696045, 'z': 4.0},
#  {'x': 5.25, 'y': 0.9009997844696045, 'z': 6.25},
#  {'x': 5.25, 'y': 0.9009997844696045, 'z': 3.75},
#  {'x': 5.0, 'y': 0.9009997844696045, 'z': 3.5},
#  {'x': 4.75, 'y': 0.9009997844696045, 'z': 3.25},
#  {'x': 4.5, 'y': 0.9009997844696045, 'z': 3.0},
#  {'x': 4.25, 'y': 0.9009997844696045, 'z': 2.75},
#  {'x': 4.0, 'y': 0.9009997844696045, 'z': 2.5},
#  {'x': 0.25, 'y': 0.9009997844696045, 'z': 4.25},
#  {'x': 0.5, 'y': 0.9009997844696045, 'z': 4.0},
#  {'x': 0.75, 'y': 0.9009997844696045, 'z': 3.75},
#  {'x': 1.0, 'y': 0.9009997844696045, 'z': 3.5},
#  {'x': 1.25, 'y': 0.9009997844696045, 'z': 3.25},
#  {'x': 1.5, 'y': 0.9009997844696045, 'z': 3.0},
#  {'x': 1.75, 'y': 0.9009997844696045, 'z': 2.75},
#  {'x': 2.0, 'y': 0.9009997844696045, 'z': 2.5},
#  {'x': 2.25, 'y': 0.9009997844696045, 'z': 2.25},
#  {'x': 6.75, 'y': 0.9009997844696045, 'z': 5.0},
#  {'x': 6.5, 'y': 0.9009997844696045, 'z': 4.75},
#  {'x': 6.25, 'y': 0.9009997844696045, 'z': 4.5},
#  {'x': 6.0, 'y': 0.9009997844696045, 'z': 4.25},
#  {'x': 5.75, 'y': 0.9009997844696045, 'z': 4.0},
#  {'x': 5.5, 'y': 0.9009997844696045, 'z': 6.25},
#  {'x': 5.5, 'y': 0.9009997844696045, 'z': 3.75},
#  {'x': 5.25, 'y': 0.9009997844696045, 'z': 6.5},
#  {'x': 5.25, 'y': 0.9009997844696045, 'z': 3.5},
#  {'x': 4.75, 'y': 0.9009997844696045, 'z': 3.0},
#  {'x': 4.5, 'y': 0.9009997844696045, 'z': 2.75},
#  {'x': 4.25, 'y': 0.9009997844696045, 'z': 2.5},
#  {'x': 4.0, 'y': 0.9009997844696045, 'z': 2.25},
#  {'x': 0.25, 'y': 0.9009997844696045, 'z': 4.0},
#  {'x': 0.5, 'y': 0.9009997844696045, 'z': 3.75},
#  {'x': 0.75, 'y': 0.9009997844696045, 'z': 3.5},
#  {'x': 1.0, 'y': 0.9009997844696045, 'z': 3.25},
#  {'x': 1.25, 'y': 0.9009997844696045, 'z': 3.0},
#  {'x': 1.5, 'y': 0.9009997844696045, 'z': 2.75},
#  {'x': 1.75, 'y': 0.9009997844696045, 'z': 2.5},
#  {'x': 2.0, 'y': 0.9009997844696045, 'z': 2.25},
#  {'x': 2.25, 'y': 0.9009997844696045, 'z': 2.0},
#  {'x': 7.0, 'y': 0.9009997844696045, 'z': 5.0},
#  {'x': 6.75, 'y': 0.9009997844696045, 'z': 5.25},
#  {'x': 6.75, 'y': 0.9009997844696045, 'z': 4.75},
#  {'x': 6.5, 'y': 0.9009997844696045, 'z': 4.5},
#  {'x': 6.25, 'y': 0.9009997844696045, 'z': 4.25},
#  {'x': 6.0, 'y': 0.9009997844696045, 'z': 4.0},
#  {'x': 5.75, 'y': 0.9009997844696045, 'z': 3.75},
#  {'x': 5.5, 'y': 0.9009997844696045, 'z': 6.5},
#  {'x': 5.5, 'y': 0.9009997844696045, 'z': 3.5},
#  {'x': 5.25, 'y': 0.9009997844696045, 'z': 6.75},
#  {'x': 5.0, 'y': 0.9009997844696045, 'z': 6.5},
#  {'x': 4.75, 'y': 0.9009997844696045, 'z': 2.75},
#  {'x': 4.5, 'y': 0.9009997844696045, 'z': 2.5},
#  {'x': 4.25, 'y': 0.9009997844696045, 'z': 2.25},
#  {'x': 4.0, 'y': 0.9009997844696045, 'z': 2.0},
#  {'x': 0.25, 'y': 0.9009997844696045, 'z': 3.75},
#  {'x': 0.5, 'y': 0.9009997844696045, 'z': 3.5},
#  {'x': 0.75, 'y': 0.9009997844696045, 'z': 3.25},
#  {'x': 1.0, 'y': 0.9009997844696045, 'z': 3.0},
#  {'x': 1.25, 'y': 0.9009997844696045, 'z': 2.75},
#  {'x': 1.5, 'y': 0.9009997844696045, 'z': 2.5},
#  {'x': 1.75, 'y': 0.9009997844696045, 'z': 2.25},
#  {'x': 2.0, 'y': 0.9009997844696045, 'z': 2.0},
#  {'x': 2.25, 'y': 0.9009997844696045, 'z': 1.75},
#  {'x': 7.25, 'y': 0.9009997844696045, 'z': 5.0},
#  {'x': 7.0, 'y': 0.9009997844696045, 'z': 5.25},
#  {'x': 7.0, 'y': 0.9009997844696045, 'z': 4.75},
#  {'x': 6.75, 'y': 0.9009997844696045, 'z': 5.5},
#  {'x': 6.75, 'y': 0.9009997844696045, 'z': 4.5},
#  {'x': 6.5, 'y': 0.9009997844696045, 'z': 4.25},
#  {'x': 6.25, 'y': 0.9009997844696045, 'z': 4.0},
#  {'x': 6.0, 'y': 0.9009997844696045, 'z': 3.75},
#  {'x': 5.75, 'y': 0.9009997844696045, 'z': 3.5},
#  {'x': 5.5, 'y': 0.9009997844696045, 'z': 6.75},
#  {'x': 5.25, 'y': 0.9009997844696045, 'z': 7.0},
#  {'x': 5.0, 'y': 0.9009997844696045, 'z': 6.75},
#  {'x': 4.75, 'y': 0.9009997844696045, 'z': 6.5},
#  {'x': 4.75, 'y': 0.9009997844696045, 'z': 2.5},
#  {'x': 4.5, 'y': 0.9009997844696045, 'z': 2.25},
#  {'x': 4.25, 'y': 0.9009997844696045, 'z': 2.0},
#  {'x': 4.0, 'y': 0.9009997844696045, 'z': 1.75},
#  {'x': 0.25, 'y': 0.9009997844696045, 'z': 3.5},
#  {'x': 0.5, 'y': 0.9009997844696045, 'z': 3.25},
#  {'x': 0.75, 'y': 0.9009997844696045, 'z': 3.0},
#  {'x': 1.0, 'y': 0.9009997844696045, 'z': 2.75},
#  {'x': 1.25, 'y': 0.9009997844696045, 'z': 2.5},
#  {'x': 1.5, 'y': 0.9009997844696045, 'z': 2.25},
#  {'x': 1.75, 'y': 0.9009997844696045, 'z': 2.0},
#  {'x': 2.0, 'y': 0.9009997844696045, 'z': 1.75},
#  {'x': 2.25, 'y': 0.9009997844696045, 'z': 1.5},
#  {'x': 7.5, 'y': 0.9009997844696045, 'z': 5.0},
#  {'x': 7.25, 'y': 0.9009997844696045, 'z': 5.25},
#  {'x': 7.25, 'y': 0.9009997844696045, 'z': 4.75},
#  {'x': 7.0, 'y': 0.9009997844696045, 'z': 5.5},
#  {'x': 7.0, 'y': 0.9009997844696045, 'z': 4.5},
#  {'x': 6.75, 'y': 0.9009997844696045, 'z': 5.75},
#  {'x': 6.75, 'y': 0.9009997844696045, 'z': 4.25},
#  {'x': 6.5, 'y': 0.9009997844696045, 'z': 4.0},
#  {'x': 6.25, 'y': 0.9009997844696045, 'z': 3.75},
#  {'x': 6.0, 'y': 0.9009997844696045, 'z': 3.5},
#  {'x': 5.75, 'y': 0.9009997844696045, 'z': 3.25},
#  {'x': 5.5, 'y': 0.9009997844696045, 'z': 7.0},
#  {'x': 5.25, 'y': 0.9009997844696045, 'z': 7.25},
#  {'x': 5.0, 'y': 0.9009997844696045, 'z': 7.0},
#  {'x': 4.75, 'y': 0.9009997844696045, 'z': 6.75},
#  {'x': 4.5, 'y': 0.9009997844696045, 'z': 6.5},
#  {'x': 4.75, 'y': 0.9009997844696045, 'z': 2.25},
#  {'x': 4.5, 'y': 0.9009997844696045, 'z': 2.0},
#  {'x': 4.25, 'y': 0.9009997844696045, 'z': 1.75},
#  {'x': 4.0, 'y': 0.9009997844696045, 'z': 1.5},
#  {'x': 0.25, 'y': 0.9009997844696045, 'z': 3.25},
#  {'x': 0.75, 'y': 0.9009997844696045, 'z': 2.75},
#  {'x': 1.0, 'y': 0.9009997844696045, 'z': 2.5},
#  {'x': 1.25, 'y': 0.9009997844696045, 'z': 2.25},
#  {'x': 1.5, 'y': 0.9009997844696045, 'z': 2.0},
#  {'x': 1.75, 'y': 0.9009997844696045, 'z': 1.75},
#  {'x': 2.0, 'y': 0.9009997844696045, 'z': 1.5},
#  {'x': 2.25, 'y': 0.9009997844696045, 'z': 1.25},
#  {'x': 7.75, 'y': 0.9009997844696045, 'z': 5.0},
#  {'x': 7.5, 'y': 0.9009997844696045, 'z': 5.25},
#  {'x': 7.5, 'y': 0.9009997844696045, 'z': 4.75},
#  {'x': 7.25, 'y': 0.9009997844696045, 'z': 5.5},
#  {'x': 7.25, 'y': 0.9009997844696045, 'z': 4.5},
#  {'x': 7.0, 'y': 0.9009997844696045, 'z': 5.75},
#  {'x': 7.0, 'y': 0.9009997844696045, 'z': 4.25},
#  {'x': 6.75, 'y': 0.9009997844696045, 'z': 6.0},
#  {'x': 6.75, 'y': 0.9009997844696045, 'z': 4.0},
#  {'x': 6.5, 'y': 0.9009997844696045, 'z': 3.75},
#  {'x': 6.25, 'y': 0.9009997844696045, 'z': 3.5},
#  {'x': 6.0, 'y': 0.9009997844696045, 'z': 3.25},
#  {'x': 5.75, 'y': 0.9009997844696045, 'z': 3.0},
#  {'x': 5.5, 'y': 0.9009997844696045, 'z': 7.25},
#  {'x': 5.25, 'y': 0.9009997844696045, 'z': 7.5},
#  {'x': 5.0, 'y': 0.9009997844696045, 'z': 7.25},
#  {'x': 4.75, 'y': 0.9009997844696045, 'z': 7.0},
#  {'x': 4.5, 'y': 0.9009997844696045, 'z': 6.75},
#  {'x': 5.0, 'y': 0.9009997844696045, 'z': 2.25},
#  {'x': 4.75, 'y': 0.9009997844696045, 'z': 2.0},
#  {'x': 4.5, 'y': 0.9009997844696045, 'z': 1.75},
#  {'x': 4.25, 'y': 0.9009997844696045, 'z': 1.5},
#  {'x': 4.0, 'y': 0.9009997844696045, 'z': 1.25},
#  {'x': 0.75, 'y': 0.9009997844696045, 'z': 2.5},
#  {'x': 1.0, 'y': 0.9009997844696045, 'z': 2.25},
#  {'x': 1.25, 'y': 0.9009997844696045, 'z': 2.0},
#  {'x': 1.5, 'y': 0.9009997844696045, 'z': 1.75},
#  {'x': 1.75, 'y': 0.9009997844696045, 'z': 1.5},
#  {'x': 2.0, 'y': 0.9009997844696045, 'z': 1.25},
#  {'x': 2.25, 'y': 0.9009997844696045, 'z': 1.0},
#  {'x': 8.0, 'y': 0.9009997844696045, 'z': 5.0},
#  {'x': 7.75, 'y': 0.9009997844696045, 'z': 4.75},
#  {'x': 7.5, 'y': 0.9009997844696045, 'z': 5.5},
#  {'x': 7.5, 'y': 0.9009997844696045, 'z': 4.5},
#  {'x': 7.25, 'y': 0.9009997844696045, 'z': 5.75},
#  {'x': 7.25, 'y': 0.9009997844696045, 'z': 4.25},
#  {'x': 7.0, 'y': 0.9009997844696045, 'z': 6.0},
#  {'x': 7.0, 'y': 0.9009997844696045, 'z': 4.0},
#  {'x': 6.75, 'y': 0.9009997844696045, 'z': 6.25},
#  {'x': 6.75, 'y': 0.9009997844696045, 'z': 3.75},
#  {'x': 6.5, 'y': 0.9009997844696045, 'z': 3.5},
#  {'x': 6.25, 'y': 0.9009997844696045, 'z': 3.25},
#  {'x': 6.0, 'y': 0.9009997844696045, 'z': 3.0},
#  {'x': 5.75, 'y': 0.9009997844696045, 'z': 2.75},
#  {'x': 5.5, 'y': 0.9009997844696045, 'z': 7.5},
#  {'x': 5.25, 'y': 0.9009997844696045, 'z': 7.75},
#  {'x': 5.0, 'y': 0.9009997844696045, 'z': 7.5},
#  {'x': 4.75, 'y': 0.9009997844696045, 'z': 7.25},
#  {'x': 4.5, 'y': 0.9009997844696045, 'z': 7.0},
#  {'x': 5.25, 'y': 0.9009997844696045, 'z': 2.25},
#  {'x': 5.0, 'y': 0.9009997844696045, 'z': 2.0},
#  {'x': 4.75, 'y': 0.9009997844696045, 'z': 1.75},
#  {'x': 4.5, 'y': 0.9009997844696045, 'z': 1.5},
#  {'x': 4.25, 'y': 0.9009997844696045, 'z': 1.25},
#  {'x': 4.0, 'y': 0.9009997844696045, 'z': 1.0},
#  {'x': 0.75, 'y': 0.9009997844696045, 'z': 2.25},
#  {'x': 1.0, 'y': 0.9009997844696045, 'z': 2.0},
#  {'x': 1.25, 'y': 0.9009997844696045, 'z': 1.75},
#  {'x': 1.5, 'y': 0.9009997844696045, 'z': 1.5},
#  {'x': 1.75, 'y': 0.9009997844696045, 'z': 1.25},
#  {'x': 2.0, 'y': 0.9009997844696045, 'z': 1.0},
#  {'x': 2.25, 'y': 0.9009997844696045, 'z': 0.75},
#  {'x': 8.0, 'y': 0.9009997844696045, 'z': 4.75},
#  {'x': 7.75, 'y': 0.9009997844696045, 'z': 4.5},
#  {'x': 7.5, 'y': 0.9009997844696045, 'z': 5.75},
#  {'x': 7.5, 'y': 0.9009997844696045, 'z': 4.25},
#  {'x': 7.25, 'y': 0.9009997844696045, 'z': 6.0},
#  {'x': 7.25, 'y': 0.9009997844696045, 'z': 4.0},
#  {'x': 7.0, 'y': 0.9009997844696045, 'z': 6.25},
#  {'x': 7.0, 'y': 0.9009997844696045, 'z': 3.75},
#  {'x': 6.75, 'y': 0.9009997844696045, 'z': 6.5},
#  {'x': 6.75, 'y': 0.9009997844696045, 'z': 3.5},
#  {'x': 6.5, 'y': 0.9009997844696045, 'z': 3.25},
#  {'x': 6.25, 'y': 0.9009997844696045, 'z': 3.0},
#  {'x': 6.0, 'y': 0.9009997844696045, 'z': 2.75},
#  {'x': 5.75, 'y': 0.9009997844696045, 'z': 2.5},
#  {'x': 5.5, 'y': 0.9009997844696045, 'z': 7.75},
#  {'x': 5.25, 'y': 0.9009997844696045, 'z': 8.0},
#  {'x': 5.0, 'y': 0.9009997844696045, 'z': 7.75},
#  {'x': 4.75, 'y': 0.9009997844696045, 'z': 7.5},
#  {'x': 4.5, 'y': 0.9009997844696045, 'z': 7.25},
#  {'x': 5.5, 'y': 0.9009997844696045, 'z': 2.25},
#  {'x': 5.25, 'y': 0.9009997844696045, 'z': 2.0},
#  {'x': 5.0, 'y': 0.9009997844696045, 'z': 1.75},
#  {'x': 4.75, 'y': 0.9009997844696045, 'z': 1.5},
#  {'x': 4.5, 'y': 0.9009997844696045, 'z': 1.25},
#  {'x': 4.25, 'y': 0.9009997844696045, 'z': 1.0},
#  {'x': 4.0, 'y': 0.9009997844696045, 'z': 0.75},
#  {'x': 0.75, 'y': 0.9009997844696045, 'z': 2.0},
#  {'x': 1.0, 'y': 0.9009997844696045, 'z': 1.75},
#  {'x': 1.25, 'y': 0.9009997844696045, 'z': 1.5},
#  {'x': 1.5, 'y': 0.9009997844696045, 'z': 1.25},
#  {'x': 2.0, 'y': 0.9009997844696045, 'z': 0.75},
#  {'x': 2.5, 'y': 0.9009997844696045, 'z': 0.75},
#  {'x': 2.25, 'y': 0.9009997844696045, 'z': 0.5},
#  {'x': 8.0, 'y': 0.9009997844696045, 'z': 4.5},
#  {'x': 7.75, 'y': 0.9009997844696045, 'z': 4.25},
#  {'x': 7.5, 'y': 0.9009997844696045, 'z': 6.0},
#  {'x': 7.5, 'y': 0.9009997844696045, 'z': 4.0},
#  {'x': 7.25, 'y': 0.9009997844696045, 'z': 6.25},
#  {'x': 7.25, 'y': 0.9009997844696045, 'z': 3.75},
#  {'x': 7.0, 'y': 0.9009997844696045, 'z': 6.5},
#  {'x': 7.0, 'y': 0.9009997844696045, 'z': 3.5},
#  {'x': 6.75, 'y': 0.9009997844696045, 'z': 6.75},
#  {'x': 6.75, 'y': 0.9009997844696045, 'z': 3.25},
#  {'x': 6.5, 'y': 0.9009997844696045, 'z': 3.0},
#  {'x': 6.25, 'y': 0.9009997844696045, 'z': 2.75},
#  {'x': 6.0, 'y': 0.9009997844696045, 'z': 2.5},
#  {'x': 5.75, 'y': 0.9009997844696045, 'z': 2.25},
#  {'x': 5.5, 'y': 0.9009997844696045, 'z': 8.0},
#  {'x': 5.0, 'y': 0.9009997844696045, 'z': 8.0},
#  {'x': 4.75, 'y': 0.9009997844696045, 'z': 7.75},
#  {'x': 4.5, 'y': 0.9009997844696045, 'z': 7.5},
#  {'x': 5.5, 'y': 0.9009997844696045, 'z': 2.0},
#  {'x': 5.25, 'y': 0.9009997844696045, 'z': 1.75},
#  {'x': 5.0, 'y': 0.9009997844696045, 'z': 1.5},
#  {'x': 4.75, 'y': 0.9009997844696045, 'z': 1.25},
#  {'x': 4.5, 'y': 0.9009997844696045, 'z': 1.0},
#  {'x': 4.25, 'y': 0.9009997844696045, 'z': 0.75},
#  {'x': 3.75, 'y': 0.9009997844696045, 'z': 0.75},
#  {'x': 4.0, 'y': 0.9009997844696045, 'z': 0.5},
#  {'x': 0.75, 'y': 0.9009997844696045, 'z': 1.75},
#  {'x': 1.0, 'y': 0.9009997844696045, 'z': 1.5},
#  {'x': 1.25, 'y': 0.9009997844696045, 'z': 1.25},
#  {'x': 1.5, 'y': 0.9009997844696045, 'z': 1.0},
#  {'x': 1.75, 'y': 0.9009997844696045, 'z': 0.75},
#  {'x': 2.0, 'y': 0.9009997844696045, 'z': 0.5},
#  {'x': 2.75, 'y': 0.9009997844696045, 'z': 0.75},
#  {'x': 2.5, 'y': 0.9009997844696045, 'z': 0.5},
#  {'x': 2.25, 'y': 0.9009997844696045, 'z': 0.25},
#  {'x': 8.0, 'y': 0.9009997844696045, 'z': 4.25},
#  {'x': 7.75, 'y': 0.9009997844696045, 'z': 4.0},
#  {'x': 7.5, 'y': 0.9009997844696045, 'z': 6.25},
#  {'x': 7.5, 'y': 0.9009997844696045, 'z': 3.75},
#  {'x': 7.25, 'y': 0.9009997844696045, 'z': 6.5},
#  {'x': 7.25, 'y': 0.9009997844696045, 'z': 3.5},
#  {'x': 7.0, 'y': 0.9009997844696045, 'z': 6.75},
#  {'x': 7.0, 'y': 0.9009997844696045, 'z': 3.25},
#  {'x': 6.75, 'y': 0.9009997844696045, 'z': 7.0},
#  {'x': 6.75, 'y': 0.9009997844696045, 'z': 3.0},
#  {'x': 6.5, 'y': 0.9009997844696045, 'z': 2.75},
#  {'x': 6.25, 'y': 0.9009997844696045, 'z': 2.5},
#  {'x': 6.0, 'y': 0.9009997844696045, 'z': 2.25},
#  {'x': 5.75, 'y': 0.9009997844696045, 'z': 2.0},
#  {'x': 4.75, 'y': 0.9009997844696045, 'z': 8.0},
#  {'x': 4.5, 'y': 0.9009997844696045, 'z': 7.75},
#  {'x': 5.5, 'y': 0.9009997844696045, 'z': 1.75},
#  {'x': 5.25, 'y': 0.9009997844696045, 'z': 1.5},
#  {'x': 5.0, 'y': 0.9009997844696045, 'z': 1.25},
#  {'x': 4.75, 'y': 0.9009997844696045, 'z': 1.0},
#  {'x': 4.5, 'y': 0.9009997844696045, 'z': 0.75},
#  {'x': 4.25, 'y': 0.9009997844696045, 'z': 0.5},
#  {'x': 3.5, 'y': 0.9009997844696045, 'z': 0.75},
#  {'x': 3.75, 'y': 0.9009997844696045, 'z': 0.5},
#  {'x': 4.0, 'y': 0.9009997844696045, 'z': 0.25},
#  {'x': 0.75, 'y': 0.9009997844696045, 'z': 1.5},
#  {'x': 1.0, 'y': 0.9009997844696045, 'z': 1.25},
#  {'x': 1.25, 'y': 0.9009997844696045, 'z': 1.0},
#  {'x': 1.5, 'y': 0.9009997844696045, 'z': 0.75},
#  {'x': 1.75, 'y': 0.9009997844696045, 'z': 0.5},
#  {'x': 2.0, 'y': 0.9009997844696045, 'z': 0.25},
#  {'x': 3.0, 'y': 0.9009997844696045, 'z': 0.75},
#  {'x': 2.75, 'y': 0.9009997844696045, 'z': 0.5},
#  {'x': 8.0, 'y': 0.9009997844696045, 'z': 4.0},
#  {'x': 7.75, 'y': 0.9009997844696045, 'z': 3.75},
#  {'x': 7.5, 'y': 0.9009997844696045, 'z': 6.5},
#  {'x': 7.5, 'y': 0.9009997844696045, 'z': 3.5},
#  {'x': 7.25, 'y': 0.9009997844696045, 'z': 6.75},
#  {'x': 7.25, 'y': 0.9009997844696045, 'z': 3.25},
#  {'x': 7.0, 'y': 0.9009997844696045, 'z': 7.0},
#  {'x': 7.0, 'y': 0.9009997844696045, 'z': 3.0},
#  {'x': 6.75, 'y': 0.9009997844696045, 'z': 7.25},
#  {'x': 6.75, 'y': 0.9009997844696045, 'z': 2.75},
#  {'x': 6.5, 'y': 0.9009997844696045, 'z': 2.5},
#  {'x': 6.25, 'y': 0.9009997844696045, 'z': 2.25},
#  {'x': 6.0, 'y': 0.9009997844696045, 'z': 2.0},
#  {'x': 5.75, 'y': 0.9009997844696045, 'z': 1.75},
#  {'x': 4.5, 'y': 0.9009997844696045, 'z': 8.0},
#  {'x': 5.5, 'y': 0.9009997844696045, 'z': 1.5},
#  {'x': 5.25, 'y': 0.9009997844696045, 'z': 1.25},
#  {'x': 5.0, 'y': 0.9009997844696045, 'z': 1.0},
#  {'x': 4.75, 'y': 0.9009997844696045, 'z': 0.75},
#  {'x': 4.5, 'y': 0.9009997844696045, 'z': 0.5},
#  {'x': 3.25, 'y': 0.9009997844696045, 'z': 0.75},
#  {'x': 3.5, 'y': 0.9009997844696045, 'z': 0.5},
#  {'x': 3.75, 'y': 0.9009997844696045, 'z': 0.25},
#  {'x': 0.5, 'y': 0.9009997844696045, 'z': 1.5},
#  {'x': 0.75, 'y': 0.9009997844696045, 'z': 1.25},
#  {'x': 1.0, 'y': 0.9009997844696045, 'z': 1.0},
#  {'x': 1.25, 'y': 0.9009997844696045, 'z': 0.75},
#  {'x': 1.5, 'y': 0.9009997844696045, 'z': 0.5},
#  {'x': 1.75, 'y': 0.9009997844696045, 'z': 0.25},
#  {'x': 3.0, 'y': 0.9009997844696045, 'z': 0.5},
#  {'x': 2.75, 'y': 0.9009997844696045, 'z': 0.25},
#  {'x': 8.0, 'y': 0.9009997844696045, 'z': 3.75},
#  {'x': 7.75, 'y': 0.9009997844696045, 'z': 3.5},
#  {'x': 7.5, 'y': 0.9009997844696045, 'z': 6.75},
#  {'x': 7.25, 'y': 0.9009997844696045, 'z': 7.0},
#  {'x': 7.25, 'y': 0.9009997844696045, 'z': 3.0},
#  {'x': 7.0, 'y': 0.9009997844696045, 'z': 7.25},
#  {'x': 7.0, 'y': 0.9009997844696045, 'z': 2.75},
#  {'x': 6.75, 'y': 0.9009997844696045, 'z': 7.5},
#  {'x': 6.75, 'y': 0.9009997844696045, 'z': 2.5},
#  {'x': 6.5, 'y': 0.9009997844696045, 'z': 2.25},
#  {'x': 6.0, 'y': 0.9009997844696045, 'z': 1.75},
#  {'x': 5.75, 'y': 0.9009997844696045, 'z': 1.5},
#  {'x': 5.5, 'y': 0.9009997844696045, 'z': 1.25},
#  {'x': 5.25, 'y': 0.9009997844696045, 'z': 1.0},
#  {'x': 5.0, 'y': 0.9009997844696045, 'z': 0.75},
#  {'x': 4.75, 'y': 0.9009997844696045, 'z': 0.5},
#  {'x': 3.25, 'y': 0.9009997844696045, 'z': 0.5},
#  {'x': 0.25, 'y': 0.9009997844696045, 'z': 1.5},
#  {'x': 0.5, 'y': 0.9009997844696045, 'z': 1.25},
#  {'x': 0.75, 'y': 0.9009997844696045, 'z': 1.0},
#  {'x': 1.0, 'y': 0.9009997844696045, 'z': 0.75},
#  {'x': 1.25, 'y': 0.9009997844696045, 'z': 0.5},
#  {'x': 1.5, 'y': 0.9009997844696045, 'z': 0.25},
#  {'x': 8.25, 'y': 0.9009997844696045, 'z': 3.75},
#  {'x': 8.0, 'y': 0.9009997844696045, 'z': 3.5},
#  {'x': 7.5, 'y': 0.9009997844696045, 'z': 7.0},
#  {'x': 7.25, 'y': 0.9009997844696045, 'z': 7.25},
#  {'x': 7.25, 'y': 0.9009997844696045, 'z': 2.75},
#  {'x': 7.0, 'y': 0.9009997844696045, 'z': 7.5},
#  {'x': 7.0, 'y': 0.9009997844696045, 'z': 2.5},
#  {'x': 6.75, 'y': 0.9009997844696045, 'z': 2.25},
#  {'x': 5.25, 'y': 0.9009997844696045, 'z': 0.75},
#  {'x': 5.0, 'y': 0.9009997844696045, 'z': 0.5},
#  {'x': 0.25, 'y': 0.9009997844696045, 'z': 1.25},
#  {'x': 0.5, 'y': 0.9009997844696045, 'z': 1.0},
#  {'x': 0.75, 'y': 0.9009997844696045, 'z': 0.75},
#  {'x': 1.0, 'y': 0.9009997844696045, 'z': 0.5},
#  {'x': 1.25, 'y': 0.9009997844696045, 'z': 0.25},
#  {'x': 8.5, 'y': 0.9009997844696045, 'z': 3.75},
#  {'x': 8.25, 'y': 0.9009997844696045, 'z': 3.5},
#  {'x': 7.5, 'y': 0.9009997844696045, 'z': 7.25},
#  {'x': 7.25, 'y': 0.9009997844696045, 'z': 7.5},
#  {'x': 7.5, 'y': 0.9009997844696045, 'z': 2.75},
#  {'x': 7.25, 'y': 0.9009997844696045, 'z': 2.5},
#  {'x': 7.0, 'y': 0.9009997844696045, 'z': 2.25},
#  {'x': 5.25, 'y': 0.9009997844696045, 'z': 0.5},
#  {'x': 0.5, 'y': 0.9009997844696045, 'z': 0.75},
#  {'x': 0.75, 'y': 0.9009997844696045, 'z': 0.5},
#  {'x': 1.0, 'y': 0.9009997844696045, 'z': 0.25},
#  {'x': 8.75, 'y': 0.9009997844696045, 'z': 3.75},
#  {'x': 8.5, 'y': 0.9009997844696045, 'z': 3.5},
#  {'x': 7.5, 'y': 0.9009997844696045, 'z': 7.5},
#  {'x': 7.75, 'y': 0.9009997844696045, 'z': 2.75},
#  {'x': 7.5, 'y': 0.9009997844696045, 'z': 2.5},
#  {'x': 7.25, 'y': 0.9009997844696045, 'z': 2.25},
#  {'x': 7.0, 'y': 0.9009997844696045, 'z': 2.0},
#  {'x': 5.5, 'y': 0.9009997844696045, 'z': 0.5},
#  {'x': 0.5, 'y': 0.9009997844696045, 'z': 0.5},
#  {'x': 0.75, 'y': 0.9009997844696045, 'z': 0.25},
#  {'x': 9.0, 'y': 0.9009997844696045, 'z': 3.75},
#  {'x': 8.75, 'y': 0.9009997844696045, 'z': 4.0},
#  {'x': 8.75, 'y': 0.9009997844696045, 'z': 3.5},
#  {'x': 8.0, 'y': 0.9009997844696045, 'z': 2.75},
#  {'x': 7.75, 'y': 0.9009997844696045, 'z': 2.5},
#  {'x': 7.5, 'y': 0.9009997844696045, 'z': 2.25},
#  {'x': 5.75, 'y': 0.9009997844696045, 'z': 0.5},
#  {'x': 0.5, 'y': 0.9009997844696045, 'z': 0.25},
#  {'x': 9.25, 'y': 0.9009997844696045, 'z': 3.75},
#  {'x': 9.0, 'y': 0.9009997844696045, 'z': 4.0},
#  {'x': 9.0, 'y': 0.9009997844696045, 'z': 3.5},
#  {'x': 8.75, 'y': 0.9009997844696045, 'z': 4.25},
#  {'x': 8.75, 'y': 0.9009997844696045, 'z': 3.25},
#  {'x': 8.0, 'y': 0.9009997844696045, 'z': 2.5},
#  {'x': 7.75, 'y': 0.9009997844696045, 'z': 2.25},
#  {'x': 9.5, 'y': 0.9009997844696045, 'z': 3.75},
#  {'x': 9.25, 'y': 0.9009997844696045, 'z': 4.0},
#  {'x': 9.25, 'y': 0.9009997844696045, 'z': 3.5},
#  {'x': 9.0, 'y': 0.9009997844696045, 'z': 4.25},
#  {'x': 9.0, 'y': 0.9009997844696045, 'z': 3.25},
#  {'x': 8.75, 'y': 0.9009997844696045, 'z': 4.5},
#  {'x': 8.75, 'y': 0.9009997844696045, 'z': 3.0},
#  {'x': 8.0, 'y': 0.9009997844696045, 'z': 2.25},
#  {'x': 9.5, 'y': 0.9009997844696045, 'z': 4.0},
#  {'x': 9.5, 'y': 0.9009997844696045, 'z': 3.5},
#  {'x': 9.25, 'y': 0.9009997844696045, 'z': 4.25},
#  {'x': 9.25, 'y': 0.9009997844696045, 'z': 3.25},
#  {'x': 9.0, 'y': 0.9009997844696045, 'z': 4.5},
#  {'x': 9.0, 'y': 0.9009997844696045, 'z': 3.0},
#  {'x': 8.75, 'y': 0.9009997844696045, 'z': 4.75},
#  {'x': 8.75, 'y': 0.9009997844696045, 'z': 2.75},
#  {'x': 8.0, 'y': 0.9009997844696045, 'z': 2.0},
#  {'x': 9.5, 'y': 0.9009997844696045, 'z': 4.25},
#  {'x': 9.75, 'y': 0.9009997844696045, 'z': 3.5},
#  {'x': 9.5, 'y': 0.9009997844696045, 'z': 3.25},
#  {'x': 9.25, 'y': 0.9009997844696045, 'z': 4.5},
#  {'x': 9.25, 'y': 0.9009997844696045, 'z': 3.0},
#  {'x': 9.0, 'y': 0.9009997844696045, 'z': 4.75},
#  {'x': 9.0, 'y': 0.9009997844696045, 'z': 2.75},
#  {'x': 8.75, 'y': 0.9009997844696045, 'z': 5.0},
#  {'x': 8.75, 'y': 0.9009997844696045, 'z': 2.5},
#  {'x': 8.0, 'y': 0.9009997844696045, 'z': 1.75},
#  {'x': 9.5, 'y': 0.9009997844696045, 'z': 4.5},
#  {'x': 9.75, 'y': 0.9009997844696045, 'z': 3.25},
#  {'x': 9.5, 'y': 0.9009997844696045, 'z': 3.0},
#  {'x': 9.25, 'y': 0.9009997844696045, 'z': 4.75},
#  {'x': 9.25, 'y': 0.9009997844696045, 'z': 2.75},
#  {'x': 9.0, 'y': 0.9009997844696045, 'z': 5.0},
#  {'x': 9.0, 'y': 0.9009997844696045, 'z': 2.5},
#  {'x': 8.75, 'y': 0.9009997844696045, 'z': 5.25},
#  {'x': 9.75, 'y': 0.9009997844696045, 'z': 4.5},
#  {'x': 9.5, 'y': 0.9009997844696045, 'z': 4.75},
#  {'x': 10.0, 'y': 0.9009997844696045, 'z': 3.25},
#  {'x': 9.75, 'y': 0.9009997844696045, 'z': 3.0},
#  {'x': 9.5, 'y': 0.9009997844696045, 'z': 2.75},
#  {'x': 9.25, 'y': 0.9009997844696045, 'z': 5.0},
#  {'x': 9.25, 'y': 0.9009997844696045, 'z': 2.5},
#  {'x': 9.0, 'y': 0.9009997844696045, 'z': 5.25},
#  {'x': 8.75, 'y': 0.9009997844696045, 'z': 5.5},
#  {'x': 9.75, 'y': 0.9009997844696045, 'z': 4.75},
#  {'x': 9.5, 'y': 0.9009997844696045, 'z': 5.0},
#  {'x': 10.25, 'y': 0.9009997844696045, 'z': 3.25},
#  {'x': 10.0, 'y': 0.9009997844696045, 'z': 3.0},
#  {'x': 9.75, 'y': 0.9009997844696045, 'z': 2.75},
#  {'x': 9.5, 'y': 0.9009997844696045, 'z': 2.5},
#  {'x': 9.25, 'y': 0.9009997844696045, 'z': 5.25},
#  {'x': 9.0, 'y': 0.9009997844696045, 'z': 5.5},
#  {'x': 8.75, 'y': 0.9009997844696045, 'z': 5.75},
#  {'x': 10.0, 'y': 0.9009997844696045, 'z': 4.75},
#  {'x': 9.75, 'y': 0.9009997844696045, 'z': 5.0},
#  {'x': 9.5, 'y': 0.9009997844696045, 'z': 5.25},
#  {'x': 10.5, 'y': 0.9009997844696045, 'z': 3.25},
#  {'x': 10.25, 'y': 0.9009997844696045, 'z': 3.0},
#  {'x': 10.0, 'y': 0.9009997844696045, 'z': 2.75},
#  {'x': 9.75, 'y': 0.9009997844696045, 'z': 2.5},
#  {'x': 9.25, 'y': 0.9009997844696045, 'z': 5.5},
#  {'x': 9.0, 'y': 0.9009997844696045, 'z': 5.75},
#  {'x': 8.75, 'y': 0.9009997844696045, 'z': 6.0},
#  {'x': 10.0, 'y': 0.9009997844696045, 'z': 5.0},
#  {'x': 9.75, 'y': 0.9009997844696045, 'z': 5.25},
#  {'x': 9.5, 'y': 0.9009997844696045, 'z': 5.5},
#  {'x': 10.5, 'y': 0.9009997844696045, 'z': 3.0},
#  {'x': 10.25, 'y': 0.9009997844696045, 'z': 2.75},
#  {'x': 10.0, 'y': 0.9009997844696045, 'z': 2.5},
#  {'x': 9.25, 'y': 0.9009997844696045, 'z': 5.75},
#  {'x': 9.0, 'y': 0.9009997844696045, 'z': 6.0},
#  {'x': 8.75, 'y': 0.9009997844696045, 'z': 6.25},
#  {'x': 10.25, 'y': 0.9009997844696045, 'z': 5.0},
#  {'x': 10.0, 'y': 0.9009997844696045, 'z': 5.25},
#  {'x': 9.75, 'y': 0.9009997844696045, 'z': 5.5},
#  {'x': 9.5, 'y': 0.9009997844696045, 'z': 5.75},
#  {'x': 10.75, 'y': 0.9009997844696045, 'z': 3.0},
#  {'x': 10.5, 'y': 0.9009997844696045, 'z': 2.75},
#  {'x': 10.25, 'y': 0.9009997844696045, 'z': 2.5},
#  {'x': 9.25, 'y': 0.9009997844696045, 'z': 6.0},
#  {'x': 9.0, 'y': 0.9009997844696045, 'z': 6.25},
#  {'x': 8.75, 'y': 0.9009997844696045, 'z': 6.5},
#  {'x': 10.5, 'y': 0.9009997844696045, 'z': 5.0},
#  {'x': 10.25, 'y': 0.9009997844696045, 'z': 5.25},
#  {'x': 10.0, 'y': 0.9009997844696045, 'z': 5.5},
#  {'x': 9.75, 'y': 0.9009997844696045, 'z': 5.75},
#  {'x': 9.5, 'y': 0.9009997844696045, 'z': 6.0},
#  {'x': 11.0, 'y': 0.9009997844696045, 'z': 3.0},
#  {'x': 10.75, 'y': 0.9009997844696045, 'z': 2.75},
#  {'x': 10.5, 'y': 0.9009997844696045, 'z': 2.5},
#  {'x': 9.25, 'y': 0.9009997844696045, 'z': 6.25},
#  {'x': 9.0, 'y': 0.9009997844696045, 'z': 6.5},
#  {'x': 8.75, 'y': 0.9009997844696045, 'z': 6.75},
#  {'x': 10.75, 'y': 0.9009997844696045, 'z': 5.0},
#  {'x': 10.5, 'y': 0.9009997844696045, 'z': 5.25},
#  {'x': 10.25, 'y': 0.9009997844696045, 'z': 5.5},
#  {'x': 10.0, 'y': 0.9009997844696045, 'z': 5.75},
#  {'x': 9.75, 'y': 0.9009997844696045, 'z': 6.0},
#  {'x': 9.5, 'y': 0.9009997844696045, 'z': 6.25},
#  {'x': 11.25, 'y': 0.9009997844696045, 'z': 3.0},
#  {'x': 11.0, 'y': 0.9009997844696045, 'z': 3.25},
#  {'x': 11.0, 'y': 0.9009997844696045, 'z': 2.75},
#  {'x': 10.75, 'y': 0.9009997844696045, 'z': 2.5},
#  {'x': 9.25, 'y': 0.9009997844696045, 'z': 6.5},
#  {'x': 9.0, 'y': 0.9009997844696045, 'z': 6.75},
#  {'x': 8.75, 'y': 0.9009997844696045, 'z': 7.0},
#  {'x': 11.0, 'y': 0.9009997844696045, 'z': 5.0},
#  {'x': 10.0, 'y': 0.9009997844696045, 'z': 6.0},
#  {'x': 9.75, 'y': 0.9009997844696045, 'z': 6.25},
#  {'x': 9.5, 'y': 0.9009997844696045, 'z': 6.5},
#  {'x': 11.5, 'y': 0.9009997844696045, 'z': 3.0},
#  {'x': 11.25, 'y': 0.9009997844696045, 'z': 3.25},
#  {'x': 11.25, 'y': 0.9009997844696045, 'z': 2.75},
#  {'x': 11.0, 'y': 0.9009997844696045, 'z': 2.5},
#  {'x': 9.25, 'y': 0.9009997844696045, 'z': 6.75},
#  {'x': 9.0, 'y': 0.9009997844696045, 'z': 7.0},
#  {'x': 8.75, 'y': 0.9009997844696045, 'z': 7.25},
#  {'x': 11.25, 'y': 0.9009997844696045, 'z': 5.0},
#  {'x': 11.0, 'y': 0.9009997844696045, 'z': 4.75},
#  {'x': 10.0, 'y': 0.9009997844696045, 'z': 6.25},
#  {'x': 9.75, 'y': 0.9009997844696045, 'z': 6.5},
#  {'x': 9.5, 'y': 0.9009997844696045, 'z': 6.75},
#  {'x': 11.75, 'y': 0.9009997844696045, 'z': 3.0},
#  {'x': 11.5, 'y': 0.9009997844696045, 'z': 3.25},
#  {'x': 11.5, 'y': 0.9009997844696045, 'z': 2.75},
#  {'x': 11.25, 'y': 0.9009997844696045, 'z': 3.5},
#  {'x': 11.25, 'y': 0.9009997844696045, 'z': 2.5},
#  {'x': 9.25, 'y': 0.9009997844696045, 'z': 7.0},
#  {'x': 9.0, 'y': 0.9009997844696045, 'z': 7.25},
#  {'x': 8.75, 'y': 0.9009997844696045, 'z': 7.5},
#  {'x': 11.5, 'y': 0.9009997844696045, 'z': 5.0},
#  {'x': 11.25, 'y': 0.9009997844696045, 'z': 4.75},
#  {'x': 11.0, 'y': 0.9009997844696045, 'z': 4.5},
#  {'x': 9.75, 'y': 0.9009997844696045, 'z': 6.75},
#  {'x': 9.5, 'y': 0.9009997844696045, 'z': 7.0},
#  {'x': 12.0, 'y': 0.9009997844696045, 'z': 3.0},
#  {'x': 11.75, 'y': 0.9009997844696045, 'z': 3.25},
#  {'x': 11.75, 'y': 0.9009997844696045, 'z': 2.75},
#  {'x': 11.5, 'y': 0.9009997844696045, 'z': 3.5},
#  {'x': 11.5, 'y': 0.9009997844696045, 'z': 2.5},
#  {'x': 11.25, 'y': 0.9009997844696045, 'z': 3.75},
#  {'x': 9.25, 'y': 0.9009997844696045, 'z': 7.25},
#  {'x': 9.0, 'y': 0.9009997844696045, 'z': 7.5},
#  {'x': 8.75, 'y': 0.9009997844696045, 'z': 7.75},
#  {'x': 11.75, 'y': 0.9009997844696045, 'z': 5.0},
#  {'x': 11.5, 'y': 0.9009997844696045, 'z': 5.25},
#  {'x': 11.5, 'y': 0.9009997844696045, 'z': 4.75},
#  {'x': 11.25, 'y': 0.9009997844696045, 'z': 4.5},
#  {'x': 9.75, 'y': 0.9009997844696045, 'z': 7.0},
#  {'x': 9.5, 'y': 0.9009997844696045, 'z': 7.25},
#  {'x': 12.25, 'y': 0.9009997844696045, 'z': 3.0},
#  {'x': 12.0, 'y': 0.9009997844696045, 'z': 3.25},
#  {'x': 12.0, 'y': 0.9009997844696045, 'z': 2.75},
#  {'x': 11.75, 'y': 0.9009997844696045, 'z': 3.5},
#  {'x': 11.75, 'y': 0.9009997844696045, 'z': 2.5},
#  {'x': 11.5, 'y': 0.9009997844696045, 'z': 3.75},
#  {'x': 11.25, 'y': 0.9009997844696045, 'z': 4.0},
#  {'x': 9.25, 'y': 0.9009997844696045, 'z': 7.5},
#  {'x': 9.0, 'y': 0.9009997844696045, 'z': 7.75},
#  {'x': 12.0, 'y': 0.9009997844696045, 'z': 5.0},
#  {'x': 11.75, 'y': 0.9009997844696045, 'z': 5.25},
#  {'x': 11.75, 'y': 0.9009997844696045, 'z': 4.75},
#  {'x': 11.5, 'y': 0.9009997844696045, 'z': 5.5},
#  {'x': 11.5, 'y': 0.9009997844696045, 'z': 4.5},
#  {'x': 11.25, 'y': 0.9009997844696045, 'z': 4.25},
#  {'x': 9.75, 'y': 0.9009997844696045, 'z': 7.25},
#  {'x': 9.5, 'y': 0.9009997844696045, 'z': 7.5},
#  {'x': 12.5, 'y': 0.9009997844696045, 'z': 3.0},
#  {'x': 12.25, 'y': 0.9009997844696045, 'z': 3.25},
#  {'x': 12.25, 'y': 0.9009997844696045, 'z': 2.75},
#  {'x': 12.0, 'y': 0.9009997844696045, 'z': 3.5},
#  {'x': 12.0, 'y': 0.9009997844696045, 'z': 2.5},
#  {'x': 11.75, 'y': 0.9009997844696045, 'z': 3.75},
#  {'x': 11.5, 'y': 0.9009997844696045, 'z': 4.0},
#  {'x': 9.25, 'y': 0.9009997844696045, 'z': 7.75},
#  {'x': 12.25, 'y': 0.9009997844696045, 'z': 5.0},
#  {'x': 12.0, 'y': 0.9009997844696045, 'z': 5.25},
#  {'x': 12.0, 'y': 0.9009997844696045, 'z': 4.75},
#  {'x': 11.75, 'y': 0.9009997844696045, 'z': 5.5},
#  {'x': 11.75, 'y': 0.9009997844696045, 'z': 4.5},
#  {'x': 11.5, 'y': 0.9009997844696045, 'z': 4.25},
#  {'x': 10.0, 'y': 0.9009997844696045, 'z': 7.25},
#  {'x': 9.75, 'y': 0.9009997844696045, 'z': 7.5},
#  {'x': 9.5, 'y': 0.9009997844696045, 'z': 7.75},
#  {'x': 12.75, 'y': 0.9009997844696045, 'z': 3.0},
#  {'x': 12.5, 'y': 0.9009997844696045, 'z': 3.25},
#  {'x': 12.5, 'y': 0.9009997844696045, 'z': 2.75},
#  {'x': 12.25, 'y': 0.9009997844696045, 'z': 3.5},
#  {'x': 12.25, 'y': 0.9009997844696045, 'z': 2.5},
#  {'x': 12.0, 'y': 0.9009997844696045, 'z': 3.75},
#  {'x': 11.75, 'y': 0.9009997844696045, 'z': 4.0},
#  {'x': 9.25, 'y': 0.9009997844696045, 'z': 8.0},
#  {'x': 12.25, 'y': 0.9009997844696045, 'z': 5.25},
#  {'x': 12.25, 'y': 0.9009997844696045, 'z': 4.75},
#  {'x': 12.0, 'y': 0.9009997844696045, 'z': 5.5},
#  {'x': 12.0, 'y': 0.9009997844696045, 'z': 4.5},
#  {'x': 11.75, 'y': 0.9009997844696045, 'z': 5.75},
#  {'x': 11.75, 'y': 0.9009997844696045, 'z': 4.25},
#  {'x': 10.0, 'y': 0.9009997844696045, 'z': 7.5},
#  {'x': 9.75, 'y': 0.9009997844696045, 'z': 7.75},
#  {'x': 9.5, 'y': 0.9009997844696045, 'z': 8.0},
#  {'x': 13.0, 'y': 0.9009997844696045, 'z': 3.0},
#  {'x': 12.75, 'y': 0.9009997844696045, 'z': 3.25},
#  {'x': 12.75, 'y': 0.9009997844696045, 'z': 2.75},
#  {'x': 12.5, 'y': 0.9009997844696045, 'z': 3.5},
#  {'x': 12.5, 'y': 0.9009997844696045, 'z': 2.5},
#  {'x': 12.25, 'y': 0.9009997844696045, 'z': 3.75},
#  {'x': 12.25, 'y': 0.9009997844696045, 'z': 2.25},
#  {'x': 12.0, 'y': 0.9009997844696045, 'z': 4.0},
#  {'x': 12.25, 'y': 0.9009997844696045, 'z': 5.5},
#  {'x': 12.25, 'y': 0.9009997844696045, 'z': 4.5},
#  {'x': 12.0, 'y': 0.9009997844696045, 'z': 5.75},
#  {'x': 12.0, 'y': 0.9009997844696045, 'z': 4.25},
#  {'x': 11.75, 'y': 0.9009997844696045, 'z': 6.0},
#  {'x': 10.0, 'y': 0.9009997844696045, 'z': 7.75},
#  {'x': 9.75, 'y': 0.9009997844696045, 'z': 8.0},
#  {'x': 13.25, 'y': 0.9009997844696045, 'z': 3.0},
#  {'x': 13.0, 'y': 0.9009997844696045, 'z': 3.25},
#  {'x': 13.0, 'y': 0.9009997844696045, 'z': 2.75},
#  {'x': 12.75, 'y': 0.9009997844696045, 'z': 3.5},
#  {'x': 12.75, 'y': 0.9009997844696045, 'z': 2.5},
#  {'x': 12.5, 'y': 0.9009997844696045, 'z': 2.25},
#  {'x': 12.25, 'y': 0.9009997844696045, 'z': 4.0},
#  {'x': 12.25, 'y': 0.9009997844696045, 'z': 2.0},
#  {'x': 12.25, 'y': 0.9009997844696045, 'z': 5.75},
#  {'x': 12.25, 'y': 0.9009997844696045, 'z': 4.25},
#  {'x': 12.0, 'y': 0.9009997844696045, 'z': 6.0},
#  {'x': 11.75, 'y': 0.9009997844696045, 'z': 6.25},
#  {'x': 10.25, 'y': 0.9009997844696045, 'z': 7.75},
#  {'x': 10.0, 'y': 0.9009997844696045, 'z': 8.0},
#  {'x': 13.5, 'y': 0.9009997844696045, 'z': 3.0},
#  {'x': 13.25, 'y': 0.9009997844696045, 'z': 3.25},
#  {'x': 13.25, 'y': 0.9009997844696045, 'z': 2.75},
#  {'x': 13.0, 'y': 0.9009997844696045, 'z': 3.5},
#  {'x': 13.0, 'y': 0.9009997844696045, 'z': 2.5},
#  {'x': 12.75, 'y': 0.9009997844696045, 'z': 2.25},
#  {'x': 12.5, 'y': 0.9009997844696045, 'z': 2.0},
#  {'x': 12.25, 'y': 0.9009997844696045, 'z': 1.75},
#  {'x': 12.25, 'y': 0.9009997844696045, 'z': 6.0},
#  {'x': 12.0, 'y': 0.9009997844696045, 'z': 6.25},
#  {'x': 10.25, 'y': 0.9009997844696045, 'z': 8.0},
#  {'x': 13.75, 'y': 0.9009997844696045, 'z': 3.0},
#  {'x': 13.5, 'y': 0.9009997844696045, 'z': 3.25},
#  {'x': 13.5, 'y': 0.9009997844696045, 'z': 2.75},
#  {'x': 13.25, 'y': 0.9009997844696045, 'z': 3.5},
#  {'x': 13.25, 'y': 0.9009997844696045, 'z': 2.5},
#  {'x': 13.0, 'y': 0.9009997844696045, 'z': 2.25},
#  {'x': 12.75, 'y': 0.9009997844696045, 'z': 2.0},
#  {'x': 12.5, 'y': 0.9009997844696045, 'z': 1.75},
#  {'x': 12.25, 'y': 0.9009997844696045, 'z': 1.5},
#  {'x': 12.25, 'y': 0.9009997844696045, 'z': 6.25},
#  {'x': 14.0, 'y': 0.9009997844696045, 'z': 3.0},
#  {'x': 13.75, 'y': 0.9009997844696045, 'z': 3.25},
#  {'x': 13.75, 'y': 0.9009997844696045, 'z': 2.75},
#  {'x': 13.5, 'y': 0.9009997844696045, 'z': 3.5},
#  {'x': 13.5, 'y': 0.9009997844696045, 'z': 2.5},
#  {'x': 13.25, 'y': 0.9009997844696045, 'z': 2.25},
#  {'x': 13.0, 'y': 0.9009997844696045, 'z': 2.0},
#  {'x': 12.75, 'y': 0.9009997844696045, 'z': 1.75},
#  {'x': 12.5, 'y': 0.9009997844696045, 'z': 1.5},
#  {'x': 12.25, 'y': 0.9009997844696045, 'z': 1.25},
#  {'x': 12.25, 'y': 0.9009997844696045, 'z': 6.5},
#  {'x': 14.25, 'y': 0.9009997844696045, 'z': 3.0},
#  {'x': 14.0, 'y': 0.9009997844696045, 'z': 3.25},
#  {'x': 14.0, 'y': 0.9009997844696045, 'z': 2.75},
#  {'x': 13.75, 'y': 0.9009997844696045, 'z': 3.5},
#  {'x': 13.75, 'y': 0.9009997844696045, 'z': 2.5},
#  {'x': 13.5, 'y': 0.9009997844696045, 'z': 2.25},
#  {'x': 13.25, 'y': 0.9009997844696045, 'z': 2.0},
#  {'x': 13.0, 'y': 0.9009997844696045, 'z': 1.75},
#  {'x': 12.75, 'y': 0.9009997844696045, 'z': 1.5},
#  {'x': 12.5, 'y': 0.9009997844696045, 'z': 1.25},
#  {'x': 12.25, 'y': 0.9009997844696045, 'z': 1.0},
#  {'x': 12.25, 'y': 0.9009997844696045, 'z': 6.75},
#  {'x': 14.25, 'y': 0.9009997844696045, 'z': 3.25},
#  {'x': 14.25, 'y': 0.9009997844696045, 'z': 2.75},
#  {'x': 14.0, 'y': 0.9009997844696045, 'z': 3.5},
#  {'x': 14.0, 'y': 0.9009997844696045, 'z': 2.5},
#  {'x': 13.5, 'y': 0.9009997844696045, 'z': 2.0},
#  {'x': 13.25, 'y': 0.9009997844696045, 'z': 1.75},
#  {'x': 13.0, 'y': 0.9009997844696045, 'z': 1.5},
#  {'x': 12.75, 'y': 0.9009997844696045, 'z': 1.25},
#  {'x': 12.5, 'y': 0.9009997844696045, 'z': 1.0},
#  {'x': 12.25, 'y': 0.9009997844696045, 'z': 0.75},
#  {'x': 12.25, 'y': 0.9009997844696045, 'z': 7.0},
#  {'x': 12.0, 'y': 0.9009997844696045, 'z': 6.75},
#  {'x': 14.25, 'y': 0.9009997844696045, 'z': 3.5},
#  {'x': 14.25, 'y': 0.9009997844696045, 'z': 2.5},
#  {'x': 13.5, 'y': 0.9009997844696045, 'z': 1.75},
#  {'x': 13.25, 'y': 0.9009997844696045, 'z': 1.5},
#  {'x': 13.0, 'y': 0.9009997844696045, 'z': 1.25},
#  {'x': 12.75, 'y': 0.9009997844696045, 'z': 1.0},
#  {'x': 12.5, 'y': 0.9009997844696045, 'z': 0.75},
#  {'x': 12.0, 'y': 0.9009997844696045, 'z': 0.75},
#  {'x': 12.25, 'y': 0.9009997844696045, 'z': 0.5},
#  {'x': 12.25, 'y': 0.9009997844696045, 'z': 7.25},
#  {'x': 12.0, 'y': 0.9009997844696045, 'z': 7.0},
#  {'x': 13.5, 'y': 0.9009997844696045, 'z': 1.5},
#  {'x': 13.25, 'y': 0.9009997844696045, 'z': 1.25},
#  {'x': 13.0, 'y': 0.9009997844696045, 'z': 1.0},
#  {'x': 12.75, 'y': 0.9009997844696045, 'z': 0.75},
#  {'x': 12.5, 'y': 0.9009997844696045, 'z': 0.5},
#  {'x': 11.75, 'y': 0.9009997844696045, 'z': 0.75},
#  {'x': 12.0, 'y': 0.9009997844696045, 'z': 0.5},
#  {'x': 12.25, 'y': 0.9009997844696045, 'z': 0.25},
#  {'x': 12.25, 'y': 0.9009997844696045, 'z': 7.5},
#  {'x': 12.0, 'y': 0.9009997844696045, 'z': 7.25},
#  {'x': 13.5, 'y': 0.9009997844696045, 'z': 1.25},
#  {'x': 13.25, 'y': 0.9009997844696045, 'z': 1.0},
#  {'x': 13.0, 'y': 0.9009997844696045, 'z': 0.75},
#  {'x': 12.75, 'y': 0.9009997844696045, 'z': 0.5},
#  {'x': 12.5, 'y': 0.9009997844696045, 'z': 0.25},
#  {'x': 11.75, 'y': 0.9009997844696045, 'z': 1.0},
#  {'x': 11.5, 'y': 0.9009997844696045, 'z': 0.75},
#  {'x': 11.75, 'y': 0.9009997844696045, 'z': 0.5},
#  {'x': 12.0, 'y': 0.9009997844696045, 'z': 0.25},
#  {'x': 12.25, 'y': 0.9009997844696045, 'z': 7.75},
#  {'x': 12.0, 'y': 0.9009997844696045, 'z': 7.5},
#  {'x': 11.75, 'y': 0.9009997844696045, 'z': 7.25},
#  {'x': 13.5, 'y': 0.9009997844696045, 'z': 1.0},
#  {'x': 13.25, 'y': 0.9009997844696045, 'z': 0.75},
#  {'x': 13.0, 'y': 0.9009997844696045, 'z': 0.5},
#  {'x': 12.75, 'y': 0.9009997844696045, 'z': 0.25},
#  {'x': 11.5, 'y': 0.9009997844696045, 'z': 1.0},
#  {'x': 11.25, 'y': 0.9009997844696045, 'z': 0.75},
#  {'x': 11.5, 'y': 0.9009997844696045, 'z': 0.5},
#  {'x': 11.75, 'y': 0.9009997844696045, 'z': 0.25},
#  {'x': 12.25, 'y': 0.9009997844696045, 'z': 8.0},
#  {'x': 12.0, 'y': 0.9009997844696045, 'z': 7.75},
#  {'x': 11.75, 'y': 0.9009997844696045, 'z': 7.5},
#  {'x': 13.5, 'y': 0.9009997844696045, 'z': 0.75},
#  {'x': 13.25, 'y': 0.9009997844696045, 'z': 0.5},
#  {'x': 13.0, 'y': 0.9009997844696045, 'z': 0.25},
#  {'x': 11.5, 'y': 0.9009997844696045, 'z': 1.25},
#  {'x': 11.25, 'y': 0.9009997844696045, 'z': 1.0},
#  {'x': 11.0, 'y': 0.9009997844696045, 'z': 0.75},
#  {'x': 11.25, 'y': 0.9009997844696045, 'z': 0.5},
#  {'x': 11.5, 'y': 0.9009997844696045, 'z': 0.25},
#  {'x': 12.25, 'y': 0.9009997844696045, 'z': 8.25},
#  {'x': 12.0, 'y': 0.9009997844696045, 'z': 8.0},
#  {'x': 11.75, 'y': 0.9009997844696045, 'z': 7.75},
#  {'x': 13.75, 'y': 0.9009997844696045, 'z': 0.75},
#  {'x': 13.5, 'y': 0.9009997844696045, 'z': 0.5},
#  {'x': 13.25, 'y': 0.9009997844696045, 'z': 0.25},
#  {'x': 11.5, 'y': 0.9009997844696045, 'z': 1.5},
#  {'x': 11.25, 'y': 0.9009997844696045, 'z': 1.25},
#  {'x': 11.0, 'y': 0.9009997844696045, 'z': 1.0},
#  {'x': 10.75, 'y': 0.9009997844696045, 'z': 0.75},
#  {'x': 11.0, 'y': 0.9009997844696045, 'z': 0.5},
#  {'x': 11.25, 'y': 0.9009997844696045, 'z': 0.25},
#  {'x': 12.25, 'y': 0.9009997844696045, 'z': 8.5},
#  {'x': 12.0, 'y': 0.9009997844696045, 'z': 8.25},
#  {'x': 11.75, 'y': 0.9009997844696045, 'z': 8.0},
#  {'x': 14.0, 'y': 0.9009997844696045, 'z': 0.75},
#  {'x': 13.75, 'y': 0.9009997844696045, 'z': 0.5},
#  {'x': 13.5, 'y': 0.9009997844696045, 'z': 0.25},
#  {'x': 11.0, 'y': 0.9009997844696045, 'z': 1.25},
#  {'x': 10.75, 'y': 0.9009997844696045, 'z': 1.0},
#  {'x': 10.5, 'y': 0.9009997844696045, 'z': 0.75},
#  {'x': 10.75, 'y': 0.9009997844696045, 'z': 0.5},
#  {'x': 11.0, 'y': 0.9009997844696045, 'z': 0.25},
#  {'x': 12.25, 'y': 0.9009997844696045, 'z': 8.75},
#  {'x': 12.0, 'y': 0.9009997844696045, 'z': 8.5},
#  {'x': 11.75, 'y': 0.9009997844696045, 'z': 8.25},
#  {'x': 11.5, 'y': 0.9009997844696045, 'z': 8.0},
#  {'x': 14.0, 'y': 0.9009997844696045, 'z': 1.0},
#  {'x': 14.0, 'y': 0.9009997844696045, 'z': 0.5},
#  {'x': 13.75, 'y': 0.9009997844696045, 'z': 0.25},
#  {'x': 10.75, 'y': 0.9009997844696045, 'z': 1.25},
#  {'x': 10.5, 'y': 0.9009997844696045, 'z': 1.0},
#  {'x': 10.25, 'y': 0.9009997844696045, 'z': 0.75},
#  {'x': 10.5, 'y': 0.9009997844696045, 'z': 0.5},
#  {'x': 10.75, 'y': 0.9009997844696045, 'z': 0.25},
#  {'x': 12.25, 'y': 0.9009997844696045, 'z': 9.0},
#  {'x': 12.0, 'y': 0.9009997844696045, 'z': 8.75},
#  {'x': 11.75, 'y': 0.9009997844696045, 'z': 8.5},
#  {'x': 11.5, 'y': 0.9009997844696045, 'z': 8.25},
#  {'x': 14.25, 'y': 0.9009997844696045, 'z': 1.0},
#  {'x': 14.0, 'y': 0.9009997844696045, 'z': 0.25},
#  {'x': 10.75, 'y': 0.9009997844696045, 'z': 1.5},
#  {'x': 10.5, 'y': 0.9009997844696045, 'z': 1.25},
#  {'x': 10.25, 'y': 0.9009997844696045, 'z': 1.0},
#  {'x': 10.0, 'y': 0.9009997844696045, 'z': 0.75},
#  {'x': 10.25, 'y': 0.9009997844696045, 'z': 0.5},
#  {'x': 10.5, 'y': 0.9009997844696045, 'z': 0.25},
#  {'x': 12.25, 'y': 0.9009997844696045, 'z': 9.25},
#  {'x': 12.0, 'y': 0.9009997844696045, 'z': 9.0},
#  {'x': 11.75, 'y': 0.9009997844696045, 'z': 8.75},
#  {'x': 11.5, 'y': 0.9009997844696045, 'z': 8.5},
#  {'x': 11.25, 'y': 0.9009997844696045, 'z': 8.25},
#  {'x': 14.25, 'y': 0.9009997844696045, 'z': 1.25},
#  {'x': 10.5, 'y': 0.9009997844696045, 'z': 1.5},
#  {'x': 10.25, 'y': 0.9009997844696045, 'z': 1.25},
#  {'x': 10.0, 'y': 0.9009997844696045, 'z': 1.0},
#  {'x': 9.75, 'y': 0.9009997844696045, 'z': 0.75},
#  {'x': 10.0, 'y': 0.9009997844696045, 'z': 0.5},
#  {'x': 10.25, 'y': 0.9009997844696045, 'z': 0.25},
#  {'x': 12.25, 'y': 0.9009997844696045, 'z': 9.5},
#  {'x': 12.0, 'y': 0.9009997844696045, 'z': 9.25},
#  {'x': 11.75, 'y': 0.9009997844696045, 'z': 9.0},
#  {'x': 11.5, 'y': 0.9009997844696045, 'z': 8.75},
#  {'x': 11.25, 'y': 0.9009997844696045, 'z': 8.5},
#  {'x': 11.0, 'y': 0.9009997844696045, 'z': 8.25},
#  {'x': 14.25, 'y': 0.9009997844696045, 'z': 1.5},
#  {'x': 10.5, 'y': 0.9009997844696045, 'z': 1.75},
#  ...]

# %% [markdown]
# And to visualize these positions, let's plot them on a scatter plot:

# %%
import matplotlib.pyplot as plt
reachable_positions = event.metadata["actionReturn"]
xs = [rp["x"] for rp in reachable_positions]
zs = [rp["z"] for rp in reachable_positions]

fig, ax = plt.subplots(1, 1)
ax.scatter(xs, zs)
ax.set_xlabel("$x$")
ax.set_ylabel("$z$")
ax.set_title("Reachable Positions in the Scene")
ax.set_aspect("equal")

# %% [markdown]
# Now, let's randomize the agent's position and rotation:

# %%
import random

position = random.choice(reachable_positions)
rotation = random.choice(range(360))
print("Teleporting the agent to", position, " with rotation", rotation)

event = controller.step(action="Teleport", position=position, rotation=rotation)

Image.fromarray(event.frame)
# Out:
# Teleporting the agent to {'x': 7.25, 'y': 0.9009997844696045, 'z': 6.25}  with rotation 149
# <PIL.Image.Image image mode=RGB size=300x300 at 0x7FF210EB0A30>

# %% [markdown]
# # Randomize Object Materials
#
# To randomize the materials of objects, we can use the `RandomizeMaterials` function:

# %%
fig, axs = plt.subplots(2, 5, figsize=(20, 8))

for ax in axs.flat:
    event = controller.step(action="RandomizeMaterials")
    ax.imshow(event.frame)
    ax.axis("off")

# %% [markdown]
# # Changing houses
#
# To switch the agent to a different house, we can use AI2-THOR's `reset` method:

# %%
new_house = dataset["train"][1]
controller.reset(scene=new_house)

get_top_down_frame()
# Out:
# <PIL.Image.Image image mode=RGB size=300x300 at 0x7FF21057D070>

# %% [markdown]
# # More Details
#
# This notebook provided a very minimal demo to get started with ProcTHOR. More about ProcTHOR will be open-sourced and documented soon.
#
# For more details about how to use AI2-THOR, please checkout the API references at [ai2thor.allenai.org](https://ai2thor.allenai.org).
